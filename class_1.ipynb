# %%
import numpy as np
import numpy as pn
import torch
import torch.nn as nn
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset
from torchsummary import summary
from torch.optim import Adam

# %%
class IrisDataset(Dataset):

    def __init__(self, X:np.ndarray, y:np.ndarray):
        super(IrisDataset, self).__init__()
        X = X.astype('float32')
        y = y.astype('int64')
        self.X = torch.from_numpy(X)
        self.y = torch.from_numpy(y)

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return len(self.X)

# %%
class Net(nn.Module):

    def __init__(self, feature_nums:int, layer_num:int):
        """
        :param feature_nums:
        :param layer_num:
        """
        super(Net, self).__init__()
        self.classifier = nn.Sequential()
        input_nums = feature_nums
        output_nums = 16
        for layer_index in range(layer_num - 1):
            self.classifier.add_module(f'Linear_layer{layer_index}',nn.Linear(input_nums, output_nums))
            self.classifier.add_module(f'Relu{layer_index}',nn.ReLU())
            input_nums = output_nums
            output_nums *= 2

        self.classifier.add_module(f'Linear_laye{layer_num - 1}', nn.Linear(input_nums, feature_nums))


    def forward(self, x)->torch.Tensor:
        return self.classifier(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
x = torch.rand((120, 4)).to(device)
net = Net(4, 6).to("cuda")
# print(net)
print(net(x))
# Out:
# cuda
# tensor([[0.0152, 0.0143, 0.0225, 0.0271],
#         [0.0186, 0.0132, 0.0140, 0.0319],
#         [0.0161, 0.0145, 0.0196, 0.0312],
#         [0.0150, 0.0141, 0.0220, 0.0269],
#         [0.0160, 0.0152, 0.0224, 0.0289],
#         [0.0146, 0.0145, 0.0207, 0.0298],
#         [0.0124, 0.0146, 0.0201, 0.0261],
#         [0.0150, 0.0148, 0.0199, 0.0301],
#         [0.0136, 0.0125, 0.0213, 0.0281],
#         [0.0171, 0.0141, 0.0225, 0.0291],
#         [0.0161, 0.0142, 0.0178, 0.0309],
#         [0.0160, 0.0134, 0.0202, 0.0310],
#         [0.0153, 0.0132, 0.0180, 0.0305],
#         [0.0155, 0.0139, 0.0224, 0.0274],
#         [0.0158, 0.0148, 0.0203, 0.0304],
#         [0.0158, 0.0142, 0.0228, 0.0267],
#         [0.0126, 0.0140, 0.0203, 0.0261],
#         [0.0141, 0.0151, 0.0225, 0.0272],
#         [0.0143, 0.0147, 0.0192, 0.0298],
#         [0.0164, 0.0148, 0.0195, 0.0312],
#         [0.0148, 0.0137, 0.0217, 0.0266],
#         [0.0148, 0.0147, 0.0210, 0.0296],
#         [0.0151, 0.0143, 0.0210, 0.0302],
#         [0.0163, 0.0138, 0.0227, 0.0277],
#         [0.0155, 0.0119, 0.0166, 0.0310],
#         [0.0146, 0.0150, 0.0223, 0.0276],
#         [0.0159, 0.0138, 0.0227, 0.0272],
#         [0.0158, 0.0134, 0.0178, 0.0309],
#         [0.0163, 0.0130, 0.0172, 0.0313],
#         [0.0146, 0.0144, 0.0223, 0.0276],
#         [0.0159, 0.0142, 0.0228, 0.0275],
#         [0.0148, 0.0147, 0.0218, 0.0284],
#         [0.0146, 0.0149, 0.0219, 0.0283],
#         [0.0162, 0.0152, 0.0219, 0.0300],
#         [0.0170, 0.0146, 0.0221, 0.0303],
#         [0.0145, 0.0141, 0.0222, 0.0258],
#         [0.0145, 0.0144, 0.0219, 0.0273],
#         [0.0141, 0.0120, 0.0199, 0.0288],
#         [0.0164, 0.0151, 0.0212, 0.0309],
#         [0.0150, 0.0142, 0.0226, 0.0264],
#         [0.0155, 0.0139, 0.0207, 0.0304],
#         [0.0138, 0.0117, 0.0187, 0.0289],
#         [0.0155, 0.0142, 0.0226, 0.0274],
#         [0.0155, 0.0151, 0.0213, 0.0306],
#         [0.0160, 0.0153, 0.0207, 0.0311],
#         [0.0134, 0.0143, 0.0209, 0.0272],
#         [0.0136, 0.0147, 0.0204, 0.0290],
#         [0.0137, 0.0147, 0.0201, 0.0293],
#         [0.0165, 0.0143, 0.0187, 0.0315],
#         [0.0166, 0.0138, 0.0224, 0.0287],
#         [0.0150, 0.0153, 0.0210, 0.0300],
#         [0.0158, 0.0142, 0.0226, 0.0276],
#         [0.0144, 0.0154, 0.0210, 0.0294],
#         [0.0143, 0.0125, 0.0210, 0.0287],
#         [0.0143, 0.0147, 0.0212, 0.0286],
#         [0.0168, 0.0147, 0.0188, 0.0317],
#         [0.0154, 0.0147, 0.0219, 0.0288],
#         [0.0150, 0.0149, 0.0207, 0.0304],
#         [0.0167, 0.0146, 0.0221, 0.0300],
#         [0.0136, 0.0138, 0.0188, 0.0293],
#         [0.0152, 0.0143, 0.0212, 0.0300],
#         [0.0151, 0.0157, 0.0225, 0.0285],
#         [0.0157, 0.0146, 0.0217, 0.0289],
#         [0.0150, 0.0135, 0.0199, 0.0297],
#         [0.0132, 0.0120, 0.0193, 0.0283],
#         [0.0142, 0.0148, 0.0225, 0.0265],
#         [0.0170, 0.0142, 0.0225, 0.0293],
#         [0.0160, 0.0152, 0.0196, 0.0313],
#         [0.0147, 0.0129, 0.0221, 0.0288],
#         [0.0120, 0.0151, 0.0187, 0.0274],
#         [0.0144, 0.0148, 0.0212, 0.0292],
#         [0.0151, 0.0153, 0.0210, 0.0299],
#         [0.0143, 0.0136, 0.0208, 0.0290],
#         [0.0160, 0.0151, 0.0201, 0.0313],
#         [0.0152, 0.0143, 0.0224, 0.0265],
#         [0.0139, 0.0138, 0.0216, 0.0258],
#         [0.0152, 0.0140, 0.0219, 0.0271],
#         [0.0156, 0.0143, 0.0227, 0.0272],
#         [0.0115, 0.0139, 0.0173, 0.0275],
#         [0.0166, 0.0150, 0.0224, 0.0295],
#         [0.0131, 0.0123, 0.0192, 0.0283],
#         [0.0158, 0.0128, 0.0195, 0.0308],
#         [0.0143, 0.0143, 0.0212, 0.0281],
#         [0.0166, 0.0143, 0.0224, 0.0291],
#         [0.0160, 0.0130, 0.0224, 0.0289],
#         [0.0151, 0.0123, 0.0190, 0.0294],
#         [0.0148, 0.0147, 0.0226, 0.0266],
#         [0.0158, 0.0133, 0.0223, 0.0282],
#         [0.0155, 0.0136, 0.0218, 0.0299],
#         [0.0158, 0.0155, 0.0212, 0.0308],
#         [0.0142, 0.0143, 0.0214, 0.0279],
#         [0.0164, 0.0149, 0.0195, 0.0315],
#         [0.0136, 0.0123, 0.0196, 0.0285],
#         [0.0155, 0.0151, 0.0223, 0.0287],
#         [0.0137, 0.0135, 0.0218, 0.0255],
#         [0.0149, 0.0141, 0.0227, 0.0255],
#         [0.0143, 0.0159, 0.0207, 0.0300],
#         [0.0147, 0.0119, 0.0199, 0.0288],
#         [0.0142, 0.0144, 0.0225, 0.0254],
#         [0.0152, 0.0126, 0.0170, 0.0298],
#         [0.0151, 0.0131, 0.0210, 0.0300],
#         [0.0162, 0.0136, 0.0223, 0.0290],
#         [0.0140, 0.0148, 0.0200, 0.0292],
#         [0.0166, 0.0152, 0.0217, 0.0306],
#         [0.0147, 0.0150, 0.0212, 0.0292],
#         [0.0158, 0.0155, 0.0215, 0.0304],
#         [0.0161, 0.0147, 0.0225, 0.0287],
#         [0.0125, 0.0139, 0.0193, 0.0280],
#         [0.0158, 0.0139, 0.0209, 0.0307],
#         [0.0150, 0.0155, 0.0209, 0.0304],
#         [0.0149, 0.0149, 0.0226, 0.0275],
#         [0.0151, 0.0141, 0.0217, 0.0270],
#         [0.0144, 0.0140, 0.0222, 0.0272],
#         [0.0157, 0.0143, 0.0196, 0.0309],
#         [0.0168, 0.0140, 0.0226, 0.0295],
#         [0.0158, 0.0152, 0.0205, 0.0311],
#         [0.0142, 0.0141, 0.0201, 0.0291],
#         [0.0127, 0.0142, 0.0203, 0.0261],
#         [0.0156, 0.0145, 0.0218, 0.0290],
#         [0.0156, 0.0128, 0.0159, 0.0301]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
iris_data = load_iris(return_X_y=True)
print(iris_data[0].shape, iris_data[1].shape)

X = iris_data[0]
y = iris_data[1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

iris_train = IrisDataset(X_train, y_train)
iris_test = IrisDataset(X_test, y_test)
# Out:
# (150, 4) (150,)

# %%
# train

net.train()

train_loader = DataLoader(iris_train, batch_size=10, shuffle=True)
test_loader = DataLoader(iris_test, batch_size=10,shuffle=False)

EPOCH = 100
net = Net(4, 4)
opt = Adam(lr=0.001, params=net.parameters())
loss_fn = nn.CrossEntropyLoss()

for epoch in range(EPOCH):

    for batch_id, (Sample_data, target) in enumerate(train_loader):

        print(Sample_data.dtype)
        predict = net(Sample_data)

        loss = loss_fn(predict, target).requires_grad_(True)
        opt.zero_grad()
        loss.backward()
        opt.step()

        print(f"epoch:{epoch}, batch_id:{batch_id}, loss:{loss}")


        # print((idx, input_data, target))
# Out:
# torch.float32
# epoch:0, batch_id:0, loss:1.4903762340545654
# torch.float32
# epoch:0, batch_id:1, loss:1.4536776542663574
# torch.float32
# epoch:0, batch_id:2, loss:1.4409438371658325
# torch.float32
# epoch:0, batch_id:3, loss:1.3790836334228516
# torch.float32
# epoch:0, batch_id:4, loss:1.3325238227844238
# torch.float32
# epoch:0, batch_id:5, loss:1.388898253440857
# torch.float32
# epoch:0, batch_id:6, loss:1.3694090843200684
# torch.float32
# epoch:0, batch_id:7, loss:1.3824855089187622
# torch.float32
# epoch:0, batch_id:8, loss:1.341977596282959
# torch.float32
# epoch:0, batch_id:9, loss:1.2835955619812012
# torch.float32
# epoch:0, batch_id:10, loss:1.3229113817214966
# torch.float32
# epoch:0, batch_id:11, loss:1.3375552892684937
# torch.float32
# epoch:1, batch_id:0, loss:1.253288984298706
# torch.float32
# epoch:1, batch_id:1, loss:1.3224456310272217
# torch.float32
# epoch:1, batch_id:2, loss:1.2365986108779907
# torch.float32
# epoch:1, batch_id:3, loss:1.2567509412765503
# torch.float32
# epoch:1, batch_id:4, loss:1.2409226894378662
# torch.float32
# epoch:1, batch_id:5, loss:1.2287050485610962
# torch.float32
# epoch:1, batch_id:6, loss:1.2178218364715576
# torch.float32
# epoch:1, batch_id:7, loss:1.2261366844177246
# torch.float32
# epoch:1, batch_id:8, loss:1.178446650505066
# torch.float32
# epoch:1, batch_id:9, loss:1.221521258354187
# torch.float32
# epoch:1, batch_id:10, loss:1.1889851093292236
# torch.float32
# epoch:1, batch_id:11, loss:1.1919453144073486
# torch.float32
# epoch:2, batch_id:0, loss:1.1353070735931396
# torch.float32
# epoch:2, batch_id:1, loss:1.1627171039581299
# torch.float32
# epoch:2, batch_id:2, loss:1.1248183250427246
# torch.float32
# epoch:2, batch_id:3, loss:1.0958510637283325
# torch.float32
# epoch:2, batch_id:4, loss:1.1278443336486816
# torch.float32
# epoch:2, batch_id:5, loss:1.115610957145691
# torch.float32
# epoch:2, batch_id:6, loss:1.01705801486969
# torch.float32
# epoch:2, batch_id:7, loss:1.0781116485595703
# torch.float32
# epoch:2, batch_id:8, loss:1.0920753479003906
# torch.float32
# epoch:2, batch_id:9, loss:1.0110313892364502
# torch.float32
# epoch:2, batch_id:10, loss:1.0974658727645874
# torch.float32
# epoch:2, batch_id:11, loss:1.0130140781402588
# torch.float32
# epoch:3, batch_id:0, loss:0.9810401797294617
# torch.float32
# epoch:3, batch_id:1, loss:1.0597074031829834
# torch.float32
# epoch:3, batch_id:2, loss:0.9702264070510864
# torch.float32
# epoch:3, batch_id:3, loss:0.9291874170303345
# torch.float32
# epoch:3, batch_id:4, loss:0.9155869483947754
# torch.float32
# epoch:3, batch_id:5, loss:0.9366161227226257
# torch.float32
# epoch:3, batch_id:6, loss:0.9885727763175964
# torch.float32
# epoch:3, batch_id:7, loss:0.8163543939590454
# torch.float32
# epoch:3, batch_id:8, loss:0.9156777262687683
# torch.float32
# epoch:3, batch_id:9, loss:0.9978556632995605
# torch.float32
# epoch:3, batch_id:10, loss:0.8622481226921082
# torch.float32
# epoch:3, batch_id:11, loss:0.9383111000061035
# torch.float32
# epoch:4, batch_id:0, loss:0.8866934776306152
# torch.float32
# epoch:4, batch_id:1, loss:0.8823139071464539
# torch.float32
# epoch:4, batch_id:2, loss:0.6963514089584351
# torch.float32
# epoch:4, batch_id:3, loss:0.9289296865463257
# torch.float32
# epoch:4, batch_id:4, loss:0.7461002469062805
# torch.float32
# epoch:4, batch_id:5, loss:0.7880465388298035
# torch.float32
# epoch:4, batch_id:6, loss:0.9571675062179565
# torch.float32
# epoch:4, batch_id:7, loss:0.8317915201187134
# torch.float32
# epoch:4, batch_id:8, loss:0.7075003981590271
# torch.float32
# epoch:4, batch_id:9, loss:0.650772213935852
# torch.float32
# epoch:4, batch_id:10, loss:0.5611894130706787
# torch.float32
# epoch:4, batch_id:11, loss:0.8914456367492676
# torch.float32
# epoch:5, batch_id:0, loss:0.5988906621932983
# torch.float32
# epoch:5, batch_id:1, loss:0.7386654615402222
# torch.float32
# epoch:5, batch_id:2, loss:0.7111706733703613
# torch.float32
# epoch:5, batch_id:3, loss:0.6223678588867188
# torch.float32
# epoch:5, batch_id:4, loss:0.6464069485664368
# torch.float32
# epoch:5, batch_id:5, loss:0.8283461332321167
# torch.float32
# epoch:5, batch_id:6, loss:0.5555114150047302
# torch.float32
# epoch:5, batch_id:7, loss:0.6034330129623413
# torch.float32
# epoch:5, batch_id:8, loss:0.8007928729057312
# torch.float32
# epoch:5, batch_id:9, loss:0.7565338611602783
# torch.float32
# epoch:5, batch_id:10, loss:0.563564658164978
# torch.float32
# epoch:5, batch_id:11, loss:0.610273540019989
# torch.float32
# epoch:6, batch_id:0, loss:0.6959468722343445
# torch.float32
# epoch:6, batch_id:1, loss:0.5949829816818237
# torch.float32
# epoch:6, batch_id:2, loss:0.5919021368026733
# torch.float32
# epoch:6, batch_id:3, loss:0.49844321608543396
# torch.float32
# epoch:6, batch_id:4, loss:0.5674839019775391
# torch.float32
# epoch:6, batch_id:5, loss:0.5050002336502075
# torch.float32
# epoch:6, batch_id:6, loss:0.5371028780937195
# torch.float32
# epoch:6, batch_id:7, loss:0.5995627641677856
# torch.float32
# epoch:6, batch_id:8, loss:0.44898590445518494
# torch.float32
# epoch:6, batch_id:9, loss:0.49239808320999146
# torch.float32
# epoch:6, batch_id:10, loss:0.6971257328987122
# torch.float32
# epoch:6, batch_id:11, loss:0.5017998814582825
# torch.float32
# epoch:7, batch_id:0, loss:0.28567785024642944
# torch.float32
# epoch:7, batch_id:1, loss:0.645104706287384
# torch.float32
# epoch:7, batch_id:2, loss:0.5387837886810303
# torch.float32
# epoch:7, batch_id:3, loss:0.46539393067359924
# torch.float32
# epoch:7, batch_id:4, loss:0.4683160185813904
# torch.float32
# epoch:7, batch_id:5, loss:0.3632482886314392
# torch.float32
# epoch:7, batch_id:6, loss:0.4929455816745758
# torch.float32
# epoch:7, batch_id:7, loss:0.4410315155982971
# torch.float32
# epoch:7, batch_id:8, loss:0.4476775527000427
# torch.float32
# epoch:7, batch_id:9, loss:0.6343221664428711
# torch.float32
# epoch:7, batch_id:10, loss:0.605161726474762
# torch.float32
# epoch:7, batch_id:11, loss:0.4683534502983093
# torch.float32
# epoch:8, batch_id:0, loss:0.6315534114837646
# torch.float32
# epoch:8, batch_id:1, loss:0.5640905499458313
# torch.float32
# epoch:8, batch_id:2, loss:0.2833823263645172
# torch.float32
# epoch:8, batch_id:3, loss:0.6083821058273315
# torch.float32
# epoch:8, batch_id:4, loss:0.263301283121109
# torch.float32
# epoch:8, batch_id:5, loss:0.3365166485309601
# torch.float32
# epoch:8, batch_id:6, loss:0.3545173406600952
# torch.float32
# epoch:8, batch_id:7, loss:0.3824329972267151
# torch.float32
# epoch:8, batch_id:8, loss:0.4826532304286957
# torch.float32
# epoch:8, batch_id:9, loss:0.325210303068161
# torch.float32
# epoch:8, batch_id:10, loss:0.5417696833610535
# torch.float32
# epoch:8, batch_id:11, loss:0.42920297384262085
# torch.float32
# epoch:9, batch_id:0, loss:0.48301416635513306
# torch.float32
# epoch:9, batch_id:1, loss:0.35821041464805603
# torch.float32
# epoch:9, batch_id:2, loss:0.489142507314682
# torch.float32
# epoch:9, batch_id:3, loss:0.3680413067340851
# torch.float32
# epoch:9, batch_id:4, loss:0.4869362711906433
# torch.float32
# epoch:9, batch_id:5, loss:0.3402222692966461
# torch.float32
# epoch:9, batch_id:6, loss:0.379618376493454
# torch.float32
# epoch:9, batch_id:7, loss:0.2817869186401367
# torch.float32
# epoch:9, batch_id:8, loss:0.47028860449790955
# torch.float32
# epoch:9, batch_id:9, loss:0.30708956718444824
# torch.float32
# epoch:9, batch_id:10, loss:0.2925369143486023
# torch.float32
# epoch:9, batch_id:11, loss:0.43453893065452576
# torch.float32
# epoch:10, batch_id:0, loss:0.5123791694641113
# torch.float32
# epoch:10, batch_id:1, loss:0.33811038732528687
# torch.float32
# epoch:10, batch_id:2, loss:0.34409743547439575
# torch.float32
# epoch:10, batch_id:3, loss:0.3018038272857666
# torch.float32
# epoch:10, batch_id:4, loss:0.4887297749519348
# torch.float32
# epoch:10, batch_id:5, loss:0.4609591066837311
# torch.float32
# epoch:10, batch_id:6, loss:0.41947197914123535
# torch.float32
# epoch:10, batch_id:7, loss:0.21589216589927673
# torch.float32
# epoch:10, batch_id:8, loss:0.36157503724098206
# torch.float32
# epoch:10, batch_id:9, loss:0.31885892152786255
# torch.float32
# epoch:10, batch_id:10, loss:0.3139844536781311
# torch.float32
# epoch:10, batch_id:11, loss:0.34651118516921997
# torch.float32
# epoch:11, batch_id:0, loss:0.3589628338813782
# torch.float32
# epoch:11, batch_id:1, loss:0.4158913195133209
# torch.float32
# epoch:11, batch_id:2, loss:0.22717639803886414
# torch.float32
# epoch:11, batch_id:3, loss:0.3052980899810791
# torch.float32
# epoch:11, batch_id:4, loss:0.37192970514297485
# torch.float32
# epoch:11, batch_id:5, loss:0.30758342146873474
# torch.float32
# epoch:11, batch_id:6, loss:0.2793722152709961
# torch.float32
# epoch:11, batch_id:7, loss:0.3233324885368347
# torch.float32
# epoch:11, batch_id:8, loss:0.24750712513923645
# torch.float32
# epoch:11, batch_id:9, loss:0.30738914012908936
# torch.float32
# epoch:11, batch_id:10, loss:0.19671808183193207
# torch.float32
# epoch:11, batch_id:11, loss:0.4468384385108948
# torch.float32
# epoch:12, batch_id:0, loss:0.3014647960662842
# torch.float32
# epoch:12, batch_id:1, loss:0.20888002216815948
# torch.float32
# epoch:12, batch_id:2, loss:0.2613438367843628
# torch.float32
# epoch:12, batch_id:3, loss:0.24487054347991943
# torch.float32
# epoch:12, batch_id:4, loss:0.43778151273727417
# torch.float32
# epoch:12, batch_id:5, loss:0.3568018972873688
# torch.float32
# epoch:12, batch_id:6, loss:0.23653392493724823
# torch.float32
# epoch:12, batch_id:7, loss:0.38307374715805054
# torch.float32
# epoch:12, batch_id:8, loss:0.2840951681137085
# torch.float32
# epoch:12, batch_id:9, loss:0.2981926500797272
# torch.float32
# epoch:12, batch_id:10, loss:0.20077812671661377
# torch.float32
# epoch:12, batch_id:11, loss:0.1131429448723793
# torch.float32
# epoch:13, batch_id:0, loss:0.2464563399553299
# torch.float32
# epoch:13, batch_id:1, loss:0.2975921034812927
# torch.float32
# epoch:13, batch_id:2, loss:0.38204219937324524
# torch.float32
# epoch:13, batch_id:3, loss:0.16512462496757507
# torch.float32
# epoch:13, batch_id:4, loss:0.3149791359901428
# torch.float32
# epoch:13, batch_id:5, loss:0.18046867847442627
# torch.float32
# epoch:13, batch_id:6, loss:0.16162191331386566
# torch.float32
# epoch:13, batch_id:7, loss:0.3692249357700348
# torch.float32
# epoch:13, batch_id:8, loss:0.28735730051994324
# torch.float32
# epoch:13, batch_id:9, loss:0.14585238695144653
# torch.float32
# epoch:13, batch_id:10, loss:0.1852024644613266
# torch.float32
# epoch:13, batch_id:11, loss:0.1761152446269989
# torch.float32
# epoch:14, batch_id:0, loss:0.27228298783302307
# torch.float32
# epoch:14, batch_id:1, loss:0.2506280541419983
# torch.float32
# epoch:14, batch_id:2, loss:0.32661643624305725
# torch.float32
# epoch:14, batch_id:3, loss:0.34106317162513733
# torch.float32
# epoch:14, batch_id:4, loss:0.32129931449890137
# torch.float32
# epoch:14, batch_id:5, loss:0.09095054864883423
# torch.float32
# epoch:14, batch_id:6, loss:0.1786886304616928
# torch.float32
# epoch:14, batch_id:7, loss:0.23564954102039337
# torch.float32
# epoch:14, batch_id:8, loss:0.14894241094589233
# torch.float32
# epoch:14, batch_id:9, loss:0.18429112434387207
# torch.float32
# epoch:14, batch_id:10, loss:0.12736117839813232
# torch.float32
# epoch:14, batch_id:11, loss:0.328930139541626
# torch.float32
# epoch:15, batch_id:0, loss:0.18877223134040833
# torch.float32
# epoch:15, batch_id:1, loss:0.16239650547504425
# torch.float32
# epoch:15, batch_id:2, loss:0.11014582216739655
# torch.float32
# epoch:15, batch_id:3, loss:0.17982622981071472
# torch.float32
# epoch:15, batch_id:4, loss:0.13627630472183228
# torch.float32
# epoch:15, batch_id:5, loss:0.18729063868522644
# torch.float32
# epoch:15, batch_id:6, loss:0.16182276606559753
# torch.float32
# epoch:15, batch_id:7, loss:0.23446691036224365
# torch.float32
# epoch:15, batch_id:8, loss:0.28689852356910706
# torch.float32
# epoch:15, batch_id:9, loss:0.17747920751571655
# torch.float32
# epoch:15, batch_id:10, loss:0.29517582058906555
# torch.float32
# epoch:15, batch_id:11, loss:0.25772303342819214
# torch.float32
# epoch:16, batch_id:0, loss:0.17030739784240723
# torch.float32
# epoch:16, batch_id:1, loss:0.12453533709049225
# torch.float32
# epoch:16, batch_id:2, loss:0.19486065208911896
# torch.float32
# epoch:16, batch_id:3, loss:0.0888485237956047
# torch.float32
# epoch:16, batch_id:4, loss:0.10896861553192139
# torch.float32
# epoch:16, batch_id:5, loss:0.290994793176651
# torch.float32
# epoch:16, batch_id:6, loss:0.14414851367473602
# torch.float32
# epoch:16, batch_id:7, loss:0.15064285695552826
# torch.float32
# epoch:16, batch_id:8, loss:0.158254936337471
# torch.float32
# epoch:16, batch_id:9, loss:0.12047962844371796
# torch.float32
# epoch:16, batch_id:10, loss:0.1285119354724884
# torch.float32
# epoch:16, batch_id:11, loss:0.4032142758369446
# torch.float32
# epoch:17, batch_id:0, loss:0.182937353849411
# torch.float32
# epoch:17, batch_id:1, loss:0.1660670042037964
# torch.float32
# epoch:17, batch_id:2, loss:0.2541292905807495
# torch.float32
# epoch:17, batch_id:3, loss:0.15526601672172546
# torch.float32
# epoch:17, batch_id:4, loss:0.16407938301563263
# torch.float32
# epoch:17, batch_id:5, loss:0.14879046380519867
# torch.float32
# epoch:17, batch_id:6, loss:0.030622968450188637
# torch.float32
# epoch:17, batch_id:7, loss:0.09465691447257996
# torch.float32
# epoch:17, batch_id:8, loss:0.27078160643577576
# torch.float32
# epoch:17, batch_id:9, loss:0.1476021260023117
# torch.float32
# epoch:17, batch_id:10, loss:0.1403861939907074
# torch.float32
# epoch:17, batch_id:11, loss:0.12507091462612152
# torch.float32
# epoch:18, batch_id:0, loss:0.07573845982551575
# torch.float32
# epoch:18, batch_id:1, loss:0.1590423732995987
# torch.float32
# epoch:18, batch_id:2, loss:0.061634164303541183
# torch.float32
# epoch:18, batch_id:3, loss:0.28599151968955994
# torch.float32
# epoch:18, batch_id:4, loss:0.18793360888957977
# torch.float32
# epoch:18, batch_id:5, loss:0.10566715896129608
# torch.float32
# epoch:18, batch_id:6, loss:0.22833064198493958
# torch.float32
# epoch:18, batch_id:7, loss:0.19070522487163544
# torch.float32
# epoch:18, batch_id:8, loss:0.21280470490455627
# torch.float32
# epoch:18, batch_id:9, loss:0.13028475642204285
# torch.float32
# epoch:18, batch_id:10, loss:0.2825549244880676
# torch.float32
# epoch:18, batch_id:11, loss:0.11405523866415024
# torch.float32
# epoch:19, batch_id:0, loss:0.1826760470867157
# torch.float32
# epoch:19, batch_id:1, loss:0.1262863129377365
# torch.float32
# epoch:19, batch_id:2, loss:0.232952281832695
# torch.float32
# epoch:19, batch_id:3, loss:0.09602197259664536
# torch.float32
# epoch:19, batch_id:4, loss:0.07529674470424652
# torch.float32
# epoch:19, batch_id:5, loss:0.11295978724956512
# torch.float32
# epoch:19, batch_id:6, loss:0.23169557750225067
# torch.float32
# epoch:19, batch_id:7, loss:0.046768300235271454
# torch.float32
# epoch:19, batch_id:8, loss:0.1118742972612381
# torch.float32
# epoch:19, batch_id:9, loss:0.05207028239965439
# torch.float32
# epoch:19, batch_id:10, loss:0.13685396313667297
# torch.float32
# epoch:19, batch_id:11, loss:0.16152270138263702
# torch.float32
# epoch:20, batch_id:0, loss:0.17712445557117462
# torch.float32
# epoch:20, batch_id:1, loss:0.05375964567065239
# torch.float32
# epoch:20, batch_id:2, loss:0.09054026752710342
# torch.float32
# epoch:20, batch_id:3, loss:0.12736670672893524
# torch.float32
# epoch:20, batch_id:4, loss:0.04484107717871666
# torch.float32
# epoch:20, batch_id:5, loss:0.07017739117145538
# torch.float32
# epoch:20, batch_id:6, loss:0.3241726756095886
# torch.float32
# epoch:20, batch_id:7, loss:0.31404921412467957
# torch.float32
# epoch:20, batch_id:8, loss:0.1178036481142044
# torch.float32
# epoch:20, batch_id:9, loss:0.05928916856646538
# torch.float32
# epoch:20, batch_id:10, loss:0.09805789589881897
# torch.float32
# epoch:20, batch_id:11, loss:0.1294483244419098
# torch.float32
# epoch:21, batch_id:0, loss:0.06735983490943909
# torch.float32
# epoch:21, batch_id:1, loss:0.21884861588478088
# torch.float32
# epoch:21, batch_id:2, loss:0.04520921781659126
# torch.float32
# epoch:21, batch_id:3, loss:0.11459553241729736
# torch.float32
# epoch:21, batch_id:4, loss:0.09227269142866135
# torch.float32
# epoch:21, batch_id:5, loss:0.08550143241882324
# torch.float32
# epoch:21, batch_id:6, loss:0.05299164727330208
# torch.float32
# epoch:21, batch_id:7, loss:0.07040280103683472
# torch.float32
# epoch:21, batch_id:8, loss:0.08290939033031464
# torch.float32
# epoch:21, batch_id:9, loss:0.12380900233983994
# torch.float32
# epoch:21, batch_id:10, loss:0.5737839937210083
# torch.float32
# epoch:21, batch_id:11, loss:0.2971203029155731
# torch.float32
# epoch:22, batch_id:0, loss:0.029117396101355553
# torch.float32
# epoch:22, batch_id:1, loss:0.13221809267997742
# torch.float32
# epoch:22, batch_id:2, loss:0.05834953859448433
# torch.float32
# epoch:22, batch_id:3, loss:0.13161058723926544
# torch.float32
# epoch:22, batch_id:4, loss:0.13615106046199799
# torch.float32
# epoch:22, batch_id:5, loss:0.1347101628780365
# torch.float32
# epoch:22, batch_id:6, loss:0.07097447663545609
# torch.float32
# epoch:22, batch_id:7, loss:0.2656295895576477
# torch.float32
# epoch:22, batch_id:8, loss:0.3021748960018158
# torch.float32
# epoch:22, batch_id:9, loss:0.1308603435754776
# torch.float32
# epoch:22, batch_id:10, loss:0.033375922590494156
# torch.float32
# epoch:22, batch_id:11, loss:0.062179189175367355
# torch.float32
# epoch:23, batch_id:0, loss:0.08706937730312347
# torch.float32
# epoch:23, batch_id:1, loss:0.03098553791642189
# torch.float32
# epoch:23, batch_id:2, loss:0.21789249777793884
# torch.float32
# epoch:23, batch_id:3, loss:0.5819267630577087
# torch.float32
# epoch:23, batch_id:4, loss:0.04300748556852341
# torch.float32
# epoch:23, batch_id:5, loss:0.05345854163169861
# torch.float32
# epoch:23, batch_id:6, loss:0.11858721077442169
# torch.float32
# epoch:23, batch_id:7, loss:0.07687334716320038
# torch.float32
# epoch:23, batch_id:8, loss:0.05929350107908249
# torch.float32
# epoch:23, batch_id:9, loss:0.1315416842699051
# torch.float32
# epoch:23, batch_id:10, loss:0.020798947662115097
# torch.float32
# epoch:23, batch_id:11, loss:0.04186410456895828
# torch.float32
# epoch:24, batch_id:0, loss:0.0790342167019844
# torch.float32
# epoch:24, batch_id:1, loss:0.09201449900865555
# torch.float32
# epoch:24, batch_id:2, loss:0.27924513816833496
# torch.float32
# epoch:24, batch_id:3, loss:0.20912639796733856
# torch.float32
# epoch:24, batch_id:4, loss:0.12405680119991302
# torch.float32
# epoch:24, batch_id:5, loss:0.05052033066749573
# torch.float32
# epoch:24, batch_id:6, loss:0.10729879140853882
# torch.float32
# epoch:24, batch_id:7, loss:0.06437782198190689
# torch.float32
# epoch:24, batch_id:8, loss:0.11467530578374863
# torch.float32
# epoch:24, batch_id:9, loss:0.018453478813171387
# torch.float32
# epoch:24, batch_id:10, loss:0.04194079712033272
# torch.float32
# epoch:24, batch_id:11, loss:0.10503782331943512
# torch.float32
# epoch:25, batch_id:0, loss:0.025252679362893105
# torch.float32
# epoch:25, batch_id:1, loss:0.0543043427169323
# torch.float32
# epoch:25, batch_id:2, loss:0.24686744809150696
# torch.float32
# epoch:25, batch_id:3, loss:0.13547542691230774
# torch.float32
# epoch:25, batch_id:4, loss:0.3089156746864319
# torch.float32
# epoch:25, batch_id:5, loss:0.06518679857254028
# torch.float32
# epoch:25, batch_id:6, loss:0.06059379503130913
# torch.float32
# epoch:25, batch_id:7, loss:0.1105087399482727
# torch.float32
# epoch:25, batch_id:8, loss:0.07095003128051758
# torch.float32
# epoch:25, batch_id:9, loss:0.07814489305019379
# torch.float32
# epoch:25, batch_id:10, loss:0.01629442535340786
# torch.float32
# epoch:25, batch_id:11, loss:0.3151472508907318
# torch.float32
# epoch:26, batch_id:0, loss:0.21218156814575195
# torch.float32
# epoch:26, batch_id:1, loss:0.03936125338077545
# torch.float32
# epoch:26, batch_id:2, loss:0.026288684457540512
# torch.float32
# epoch:26, batch_id:3, loss:0.2936513125896454
# torch.float32
# epoch:26, batch_id:4, loss:0.07846619188785553
# torch.float32
# epoch:26, batch_id:5, loss:0.27828967571258545
# torch.float32
# epoch:26, batch_id:6, loss:0.07709135860204697
# torch.float32
# epoch:26, batch_id:7, loss:0.09100500494241714
# torch.float32
# epoch:26, batch_id:8, loss:0.2830488085746765
# torch.float32
# epoch:26, batch_id:9, loss:0.03250434994697571
# torch.float32
# epoch:26, batch_id:10, loss:0.029144739732146263
# torch.float32
# epoch:26, batch_id:11, loss:0.06635779142379761
# torch.float32
# epoch:27, batch_id:0, loss:0.12135916948318481
# torch.float32
# epoch:27, batch_id:1, loss:0.04963880404829979
# torch.float32
# epoch:27, batch_id:2, loss:0.31318360567092896
# torch.float32
# epoch:27, batch_id:3, loss:0.1874420940876007
# torch.float32
# epoch:27, batch_id:4, loss:0.089858278632164
# torch.float32
# epoch:27, batch_id:5, loss:0.03727561980485916
# torch.float32
# epoch:27, batch_id:6, loss:0.13817951083183289
# torch.float32
# epoch:27, batch_id:7, loss:0.06046045571565628
# torch.float32
# epoch:27, batch_id:8, loss:0.03195234388113022
# torch.float32
# epoch:27, batch_id:9, loss:0.06146356463432312
# torch.float32
# epoch:27, batch_id:10, loss:0.03079880401492119
# torch.float32
# epoch:27, batch_id:11, loss:0.01973586529493332
# torch.float32
# epoch:28, batch_id:0, loss:0.3377037048339844
# torch.float32
# epoch:28, batch_id:1, loss:0.035298001021146774
# torch.float32
# epoch:28, batch_id:2, loss:0.06695146858692169
# torch.float32
# epoch:28, batch_id:3, loss:0.04742348939180374
# torch.float32
# epoch:28, batch_id:4, loss:0.017783666029572487
# torch.float32
# epoch:28, batch_id:5, loss:0.19327013194561005
# torch.float32
# epoch:28, batch_id:6, loss:0.03355442360043526
# torch.float32
# epoch:28, batch_id:7, loss:0.06453046202659607
# torch.float32
# epoch:28, batch_id:8, loss:0.0713440477848053
# torch.float32
# epoch:28, batch_id:9, loss:0.031198617070913315
# torch.float32
# epoch:28, batch_id:10, loss:0.08936235308647156
# torch.float32
# epoch:28, batch_id:11, loss:0.08447667211294174
# torch.float32
# epoch:29, batch_id:0, loss:0.09097318351268768
# torch.float32
# epoch:29, batch_id:1, loss:0.060049496591091156
# torch.float32
# epoch:29, batch_id:2, loss:0.2666003108024597
# torch.float32
# epoch:29, batch_id:3, loss:0.02821820043027401
# torch.float32
# epoch:29, batch_id:4, loss:0.040239110589027405
# torch.float32
# epoch:29, batch_id:5, loss:0.011708224192261696
# torch.float32
# epoch:29, batch_id:6, loss:0.02121305651962757
# torch.float32
# epoch:29, batch_id:7, loss:0.059877149760723114
# torch.float32
# epoch:29, batch_id:8, loss:0.14435747265815735
# torch.float32
# epoch:29, batch_id:9, loss:0.10931549966335297
# torch.float32
# epoch:29, batch_id:10, loss:0.21571099758148193
# torch.float32
# epoch:29, batch_id:11, loss:0.014331148937344551
# torch.float32
# epoch:30, batch_id:0, loss:0.03336309641599655
# torch.float32
# epoch:30, batch_id:1, loss:0.01483298558741808
# torch.float32
# epoch:30, batch_id:2, loss:0.0688265785574913
# torch.float32
# epoch:30, batch_id:3, loss:0.02077888511121273
# torch.float32
# epoch:30, batch_id:4, loss:0.09003091603517532
# torch.float32
# epoch:30, batch_id:5, loss:0.09015808999538422
# torch.float32
# epoch:30, batch_id:6, loss:0.1936911642551422
# torch.float32
# epoch:30, batch_id:7, loss:0.09668280184268951
# torch.float32
# epoch:30, batch_id:8, loss:0.04566965252161026
# torch.float32
# epoch:30, batch_id:9, loss:0.05125228315591812
# torch.float32
# epoch:30, batch_id:10, loss:0.05664949491620064
# torch.float32
# epoch:30, batch_id:11, loss:0.2923108637332916
# torch.float32
# epoch:31, batch_id:0, loss:0.08419553935527802
# torch.float32
# epoch:31, batch_id:1, loss:0.09204988181591034
# torch.float32
# epoch:31, batch_id:2, loss:0.1498786360025406
# torch.float32
# epoch:31, batch_id:3, loss:0.01843235082924366
# torch.float32
# epoch:31, batch_id:4, loss:0.026527930051088333
# torch.float32
# epoch:31, batch_id:5, loss:0.06460848450660706
# torch.float32
# epoch:31, batch_id:6, loss:0.07871297746896744
# torch.float32
# epoch:31, batch_id:7, loss:0.2581985294818878
# torch.float32
# epoch:31, batch_id:8, loss:0.23990468680858612
# torch.float32
# epoch:31, batch_id:9, loss:0.08590163290500641
# torch.float32
# epoch:31, batch_id:10, loss:0.03882070258259773
# torch.float32
# epoch:31, batch_id:11, loss:0.08203800022602081
# torch.float32
# epoch:32, batch_id:0, loss:0.17242060601711273
# torch.float32
# epoch:32, batch_id:1, loss:0.038402073085308075
# torch.float32
# epoch:32, batch_id:2, loss:0.08546563982963562
# torch.float32
# epoch:32, batch_id:3, loss:0.06381363421678543
# torch.float32
# epoch:32, batch_id:4, loss:0.19791755080223083
# torch.float32
# epoch:32, batch_id:5, loss:0.04021816700696945
# torch.float32
# epoch:32, batch_id:6, loss:0.020455287769436836
# torch.float32
# epoch:32, batch_id:7, loss:0.007646922953426838
# torch.float32
# epoch:32, batch_id:8, loss:0.26101359724998474
# torch.float32
# epoch:32, batch_id:9, loss:0.08988817781209946
# torch.float32
# epoch:32, batch_id:10, loss:0.03601333871483803
# torch.float32
# epoch:32, batch_id:11, loss:0.01285021286457777
# torch.float32
# epoch:33, batch_id:0, loss:0.16794565320014954
# torch.float32
# epoch:33, batch_id:1, loss:0.010922925546765327
# torch.float32
# epoch:33, batch_id:2, loss:0.09889592230319977
# torch.float32
# epoch:33, batch_id:3, loss:0.014717678539454937
# torch.float32
# epoch:33, batch_id:4, loss:0.2585294246673584
# torch.float32
# epoch:33, batch_id:5, loss:0.09687258303165436
# torch.float32
# epoch:33, batch_id:6, loss:0.0832156389951706
# torch.float32
# epoch:33, batch_id:7, loss:0.016000177711248398
# torch.float32
# epoch:33, batch_id:8, loss:0.12007943540811539
# torch.float32
# epoch:33, batch_id:9, loss:0.028756607323884964
# torch.float32
# epoch:33, batch_id:10, loss:0.08293060213327408
# torch.float32
# epoch:33, batch_id:11, loss:0.04554056003689766
# torch.float32
# epoch:34, batch_id:0, loss:0.3245042562484741
# torch.float32
# epoch:34, batch_id:1, loss:0.019544117152690887
# torch.float32
# epoch:34, batch_id:2, loss:0.03314653038978577
# torch.float32
# epoch:34, batch_id:3, loss:0.031070221215486526
# torch.float32
# epoch:34, batch_id:4, loss:0.011679915711283684
# torch.float32
# epoch:34, batch_id:5, loss:0.04593093320727348
# torch.float32
# epoch:34, batch_id:6, loss:0.0860128179192543
# torch.float32
# epoch:34, batch_id:7, loss:0.14834025502204895
# torch.float32
# epoch:34, batch_id:8, loss:0.19595345854759216
# torch.float32
# epoch:34, batch_id:9, loss:0.04631325975060463
# torch.float32
# epoch:34, batch_id:10, loss:0.02243068441748619
# torch.float32
# epoch:34, batch_id:11, loss:0.02707016095519066
# torch.float32
# epoch:35, batch_id:0, loss:0.05167706683278084
# torch.float32
# epoch:35, batch_id:1, loss:0.29643672704696655
# torch.float32
# epoch:35, batch_id:2, loss:0.02437322773039341
# torch.float32
# epoch:35, batch_id:3, loss:0.04191403463482857
# torch.float32
# epoch:35, batch_id:4, loss:0.026615966111421585
# torch.float32
# epoch:35, batch_id:5, loss:0.05073942989110947
# torch.float32
# epoch:35, batch_id:6, loss:0.01451827585697174
# torch.float32
# epoch:35, batch_id:7, loss:0.08341091871261597
# torch.float32
# epoch:35, batch_id:8, loss:0.16177374124526978
# torch.float32
# epoch:35, batch_id:9, loss:0.16147801280021667
# torch.float32
# epoch:35, batch_id:10, loss:0.01010037399828434
# torch.float32
# epoch:35, batch_id:11, loss:0.09473170340061188
# torch.float32
# epoch:36, batch_id:0, loss:0.014841392636299133
# torch.float32
# epoch:36, batch_id:1, loss:0.06558795273303986
# torch.float32
# epoch:36, batch_id:2, loss:0.04513547569513321
# torch.float32
# epoch:36, batch_id:3, loss:0.044983457773923874
# torch.float32
# epoch:36, batch_id:4, loss:0.34075164794921875
# torch.float32
# epoch:36, batch_id:5, loss:0.08285117149353027
# torch.float32
# epoch:36, batch_id:6, loss:0.039606012403964996
# torch.float32
# epoch:36, batch_id:7, loss:0.30087167024612427
# torch.float32
# epoch:36, batch_id:8, loss:0.014045109041035175
# torch.float32
# epoch:36, batch_id:9, loss:0.06570401042699814
# torch.float32
# epoch:36, batch_id:10, loss:0.009462344460189342
# torch.float32
# epoch:36, batch_id:11, loss:0.0448097363114357
# torch.float32
# epoch:37, batch_id:0, loss:0.0064420150592923164
# torch.float32
# epoch:37, batch_id:1, loss:0.1716778725385666
# torch.float32
# epoch:37, batch_id:2, loss:0.1489068567752838
# torch.float32
# epoch:37, batch_id:3, loss:0.007310512010008097
# torch.float32
# epoch:37, batch_id:4, loss:0.0424501858651638
# torch.float32
# epoch:37, batch_id:5, loss:0.06376281380653381
# torch.float32
# epoch:37, batch_id:6, loss:0.204580619931221
# torch.float32
# epoch:37, batch_id:7, loss:0.04880186542868614
# torch.float32
# epoch:37, batch_id:8, loss:0.004425390157848597
# torch.float32
# epoch:37, batch_id:9, loss:0.14813756942749023
# torch.float32
# epoch:37, batch_id:10, loss:0.176325261592865
# torch.float32
# epoch:37, batch_id:11, loss:0.01698492281138897
# torch.float32
# epoch:38, batch_id:0, loss:0.06374437361955643
# torch.float32
# epoch:38, batch_id:1, loss:0.004296916536986828
# torch.float32
# epoch:38, batch_id:2, loss:0.035060983151197433
# torch.float32
# epoch:38, batch_id:3, loss:0.02720377966761589
# torch.float32
# epoch:38, batch_id:4, loss:0.06417479366064072
# torch.float32
# epoch:38, batch_id:5, loss:0.3510585129261017
# torch.float32
# epoch:38, batch_id:6, loss:0.36620357632637024
# torch.float32
# epoch:38, batch_id:7, loss:0.05814258009195328
# torch.float32
# epoch:38, batch_id:8, loss:0.025024354457855225
# torch.float32
# epoch:38, batch_id:9, loss:0.08848800510168076
# torch.float32
# epoch:38, batch_id:10, loss:0.005218463018536568
# torch.float32
# epoch:38, batch_id:11, loss:0.010114705190062523
# torch.float32
# epoch:39, batch_id:0, loss:0.1373453140258789
# torch.float32
# epoch:39, batch_id:1, loss:0.02613937482237816
# torch.float32
# epoch:39, batch_id:2, loss:0.20761048793792725
# torch.float32
# epoch:39, batch_id:3, loss:0.0962616503238678
# torch.float32
# epoch:39, batch_id:4, loss:0.0273288581520319
# torch.float32
# epoch:39, batch_id:5, loss:0.019694263115525246
# torch.float32
# epoch:39, batch_id:6, loss:0.07482320815324783
# torch.float32
# epoch:39, batch_id:7, loss:0.35615551471710205
# torch.float32
# epoch:39, batch_id:8, loss:0.01199102308601141
# torch.float32
# epoch:39, batch_id:9, loss:0.012889917008578777
# torch.float32
# epoch:39, batch_id:10, loss:0.017715197056531906
# torch.float32
# epoch:39, batch_id:11, loss:0.0029383741784840822
# torch.float32
# epoch:40, batch_id:0, loss:0.019133063033223152
# torch.float32
# epoch:40, batch_id:1, loss:0.02763146534562111
# torch.float32
# epoch:40, batch_id:2, loss:0.13750363886356354
# torch.float32
# epoch:40, batch_id:3, loss:0.045839205384254456
# torch.float32
# epoch:40, batch_id:4, loss:0.026223087683320045
# torch.float32
# epoch:40, batch_id:5, loss:0.015919087454676628
# torch.float32
# epoch:40, batch_id:6, loss:0.07265198975801468
# torch.float32
# epoch:40, batch_id:7, loss:0.07732407003641129
# torch.float32
# epoch:40, batch_id:8, loss:0.04876947030425072
# torch.float32
# epoch:40, batch_id:9, loss:0.1933746486902237
# torch.float32
# epoch:40, batch_id:10, loss:0.04432360827922821
# torch.float32
# epoch:40, batch_id:11, loss:0.2715016305446625
# torch.float32
# epoch:41, batch_id:0, loss:0.02512202039361
# torch.float32
# epoch:41, batch_id:1, loss:0.02562154456973076
# torch.float32
# epoch:41, batch_id:2, loss:0.11472877115011215
# torch.float32
# epoch:41, batch_id:3, loss:0.14605221152305603
# torch.float32
# epoch:41, batch_id:4, loss:0.10020732879638672
# torch.float32
# epoch:41, batch_id:5, loss:0.10809926688671112
# torch.float32
# epoch:41, batch_id:6, loss:0.044038042426109314
# torch.float32
# epoch:41, batch_id:7, loss:0.08589774370193481
# torch.float32
# epoch:41, batch_id:8, loss:0.07930772751569748
# torch.float32
# epoch:41, batch_id:9, loss:0.2634769678115845
# torch.float32
# epoch:41, batch_id:10, loss:0.0039176130667328835
# torch.float32
# epoch:41, batch_id:11, loss:0.03189758211374283
# torch.float32
# epoch:42, batch_id:0, loss:0.024005886167287827
# torch.float32
# epoch:42, batch_id:1, loss:0.0940619707107544
# torch.float32
# epoch:42, batch_id:2, loss:0.006305284798145294
# torch.float32
# epoch:42, batch_id:3, loss:0.022284746170043945
# torch.float32
# epoch:42, batch_id:4, loss:0.011233365163207054
# torch.float32
# epoch:42, batch_id:5, loss:0.1990451216697693
# torch.float32
# epoch:42, batch_id:6, loss:0.6648298501968384
# torch.float32
# epoch:42, batch_id:7, loss:0.00909482128918171
# torch.float32
# epoch:42, batch_id:8, loss:0.06994494795799255
# torch.float32
# epoch:42, batch_id:9, loss:0.017681783065199852
# torch.float32
# epoch:42, batch_id:10, loss:0.006345628295093775
# torch.float32
# epoch:42, batch_id:11, loss:0.1339748203754425
# torch.float32
# epoch:43, batch_id:0, loss:0.01483956165611744
# torch.float32
# epoch:43, batch_id:1, loss:0.019956229254603386
# torch.float32
# epoch:43, batch_id:2, loss:0.06495358049869537
# torch.float32
# epoch:43, batch_id:3, loss:0.00833417009562254
# torch.float32
# epoch:43, batch_id:4, loss:0.04140757769346237
# torch.float32
# epoch:43, batch_id:5, loss:0.43977054953575134
# torch.float32
# epoch:43, batch_id:6, loss:0.2184680700302124
# torch.float32
# epoch:43, batch_id:7, loss:0.07933326065540314
# torch.float32
# epoch:43, batch_id:8, loss:0.0530659444630146
# torch.float32
# epoch:43, batch_id:9, loss:0.27996736764907837
# torch.float32
# epoch:43, batch_id:10, loss:0.007010067347437143
# torch.float32
# epoch:43, batch_id:11, loss:0.011241568252444267
# torch.float32
# epoch:44, batch_id:0, loss:0.00579982902854681
# torch.float32
# epoch:44, batch_id:1, loss:0.33089110255241394
# torch.float32
# epoch:44, batch_id:2, loss:0.07227121293544769
# torch.float32
# epoch:44, batch_id:3, loss:0.20795711874961853
# torch.float32
# epoch:44, batch_id:4, loss:0.020928533747792244
# torch.float32
# epoch:44, batch_id:5, loss:0.09914927184581757
# torch.float32
# epoch:44, batch_id:6, loss:0.06669557839632034
# torch.float32
# epoch:44, batch_id:7, loss:0.00666849035769701
# torch.float32
# epoch:44, batch_id:8, loss:0.0037563715595752
# torch.float32
# epoch:44, batch_id:9, loss:0.04243234544992447
# torch.float32
# epoch:44, batch_id:10, loss:0.12540313601493835
# torch.float32
# epoch:44, batch_id:11, loss:0.014244260266423225
# torch.float32
# epoch:45, batch_id:0, loss:0.11688794940710068
# torch.float32
# epoch:45, batch_id:1, loss:0.28311994671821594
# torch.float32
# epoch:45, batch_id:2, loss:0.006177895702421665
# torch.float32
# epoch:45, batch_id:3, loss:0.024829905480146408
# torch.float32
# epoch:45, batch_id:4, loss:0.07835087925195694
# torch.float32
# epoch:45, batch_id:5, loss:0.004893664736300707
# torch.float32
# epoch:45, batch_id:6, loss:0.008780700154602528
# torch.float32
# epoch:45, batch_id:7, loss:0.09420956671237946
# torch.float32
# epoch:45, batch_id:8, loss:0.02566244639456272
# torch.float32
# epoch:45, batch_id:9, loss:0.02095319703221321
# torch.float32
# epoch:45, batch_id:10, loss:0.02077270671725273
# torch.float32
# epoch:45, batch_id:11, loss:0.2780846655368805
# torch.float32
# epoch:46, batch_id:0, loss:0.06215932220220566
# torch.float32
# epoch:46, batch_id:1, loss:0.007070318795740604
# torch.float32
# epoch:46, batch_id:2, loss:0.015399038791656494
# torch.float32
# epoch:46, batch_id:3, loss:0.158573180437088
# torch.float32
# epoch:46, batch_id:4, loss:0.006635304540395737
# torch.float32
# epoch:46, batch_id:5, loss:0.061815112829208374
# torch.float32
# epoch:46, batch_id:6, loss:0.19768215715885162
# torch.float32
# epoch:46, batch_id:7, loss:0.04399149864912033
# torch.float32
# epoch:46, batch_id:8, loss:0.11174027621746063
# torch.float32
# epoch:46, batch_id:9, loss:0.11668312549591064
# torch.float32
# epoch:46, batch_id:10, loss:0.09866480529308319
# torch.float32
# epoch:46, batch_id:11, loss:0.0359208807349205
# torch.float32
# epoch:47, batch_id:0, loss:0.0641874298453331
# torch.float32
# epoch:47, batch_id:1, loss:0.006279250141233206
# torch.float32
# epoch:47, batch_id:2, loss:0.01908944547176361
# torch.float32
# epoch:47, batch_id:3, loss:0.2376667708158493
# torch.float32
# epoch:47, batch_id:4, loss:0.06389863789081573
# torch.float32
# epoch:47, batch_id:5, loss:0.051965005695819855
# torch.float32
# epoch:47, batch_id:6, loss:0.008147531189024448
# torch.float32
# epoch:47, batch_id:7, loss:0.011935794726014137
# torch.float32
# epoch:47, batch_id:8, loss:0.03389895707368851
# torch.float32
# epoch:47, batch_id:9, loss:0.11716189235448837
# torch.float32
# epoch:47, batch_id:10, loss:0.13062307238578796
# torch.float32
# epoch:47, batch_id:11, loss:0.3242289423942566
# torch.float32
# epoch:48, batch_id:0, loss:0.08681677281856537
# torch.float32
# epoch:48, batch_id:1, loss:0.009591033682227135
# torch.float32
# epoch:48, batch_id:2, loss:0.03919805958867073
# torch.float32
# epoch:48, batch_id:3, loss:0.037095870822668076
# torch.float32
# epoch:48, batch_id:4, loss:0.09122469276189804
# torch.float32
# epoch:48, batch_id:5, loss:0.019094420596957207
# torch.float32
# epoch:48, batch_id:6, loss:0.0051977382972836494
# torch.float32
# epoch:48, batch_id:7, loss:0.36221200227737427
# torch.float32
# epoch:48, batch_id:8, loss:0.027225743979215622
# torch.float32
# epoch:48, batch_id:9, loss:0.02293039858341217
# torch.float32
# epoch:48, batch_id:10, loss:0.10600294917821884
# torch.float32
# epoch:48, batch_id:11, loss:0.031083565205335617
# torch.float32
# epoch:49, batch_id:0, loss:0.09521127492189407
# torch.float32
# epoch:49, batch_id:1, loss:0.02015133574604988
# torch.float32
# epoch:49, batch_id:2, loss:0.02669708803296089
# torch.float32
# epoch:49, batch_id:3, loss:0.07626650482416153
# torch.float32
# epoch:49, batch_id:4, loss:0.03177936375141144
# torch.float32
# epoch:49, batch_id:5, loss:0.0065296851098537445
# torch.float32
# epoch:49, batch_id:6, loss:0.015391940250992775
# torch.float32
# epoch:49, batch_id:7, loss:0.21622392535209656
# torch.float32
# epoch:49, batch_id:8, loss:0.03776128962635994
# torch.float32
# epoch:49, batch_id:9, loss:0.04764295741915703
# torch.float32
# epoch:49, batch_id:10, loss:0.42956820130348206
# torch.float32
# epoch:49, batch_id:11, loss:0.006552613340318203
# torch.float32
# epoch:50, batch_id:0, loss:0.030178770422935486
# torch.float32
# epoch:50, batch_id:1, loss:0.055088333785533905
# torch.float32
# epoch:50, batch_id:2, loss:0.05753673240542412
# torch.float32
# epoch:50, batch_id:3, loss:0.2716977000236511
# torch.float32
# epoch:50, batch_id:4, loss:0.024416247382760048
# torch.float32
# epoch:50, batch_id:5, loss:0.0053095160983502865
# torch.float32
# epoch:50, batch_id:6, loss:0.024213433265686035
# torch.float32
# epoch:50, batch_id:7, loss:0.13479262590408325
# torch.float32
# epoch:50, batch_id:8, loss:0.10757056623697281
# torch.float32
# epoch:50, batch_id:9, loss:0.003525586798787117
# torch.float32
# epoch:50, batch_id:10, loss:0.066788449883461
# torch.float32
# epoch:50, batch_id:11, loss:0.1360231339931488
# torch.float32
# epoch:51, batch_id:0, loss:0.0441972017288208
# torch.float32
# epoch:51, batch_id:1, loss:0.2728273272514343
# torch.float32
# epoch:51, batch_id:2, loss:0.0030433167703449726
# torch.float32
# epoch:51, batch_id:3, loss:0.04031103849411011
# torch.float32
# epoch:51, batch_id:4, loss:0.06412868946790695
# torch.float32
# epoch:51, batch_id:5, loss:0.1767953485250473
# torch.float32
# epoch:51, batch_id:6, loss:0.06834695488214493
# torch.float32
# epoch:51, batch_id:7, loss:0.006599040236324072
# torch.float32
# epoch:51, batch_id:8, loss:0.1038750559091568
# torch.float32
# epoch:51, batch_id:9, loss:0.06547502428293228
# torch.float32
# epoch:51, batch_id:10, loss:0.013878047466278076
# torch.float32
# epoch:51, batch_id:11, loss:0.011229068972170353
# torch.float32
# epoch:52, batch_id:0, loss:0.2961586117744446
# torch.float32
# epoch:52, batch_id:1, loss:0.005381184164434671
# torch.float32
# epoch:52, batch_id:2, loss:0.008031633682549
# torch.float32
# epoch:52, batch_id:3, loss:0.016533801332116127
# torch.float32
# epoch:52, batch_id:4, loss:0.0066914944909513
# torch.float32
# epoch:52, batch_id:5, loss:0.027910888195037842
# torch.float32
# epoch:52, batch_id:6, loss:0.1819610297679901
# torch.float32
# epoch:52, batch_id:7, loss:0.03332697972655296
# torch.float32
# epoch:52, batch_id:8, loss:0.2005486935377121
# torch.float32
# epoch:52, batch_id:9, loss:0.02931666374206543
# torch.float32
# epoch:52, batch_id:10, loss:0.012862873263657093
# torch.float32
# epoch:52, batch_id:11, loss:0.11161381006240845
# torch.float32
# epoch:53, batch_id:0, loss:0.017619842663407326
# torch.float32
# epoch:53, batch_id:1, loss:0.011130549013614655
# torch.float32
# epoch:53, batch_id:2, loss:0.26137790083885193
# torch.float32
# epoch:53, batch_id:3, loss:0.1296585500240326
# torch.float32
# epoch:53, batch_id:4, loss:0.03432980552315712
# torch.float32
# epoch:53, batch_id:5, loss:0.02820148505270481
# torch.float32
# epoch:53, batch_id:6, loss:0.0059921713545918465
# torch.float32
# epoch:53, batch_id:7, loss:0.06871703267097473
# torch.float32
# epoch:53, batch_id:8, loss:0.2960904538631439
# torch.float32
# epoch:53, batch_id:9, loss:0.06507769227027893
# torch.float32
# epoch:53, batch_id:10, loss:0.009074771776795387
# torch.float32
# epoch:53, batch_id:11, loss:0.008119484409689903
# torch.float32
# epoch:54, batch_id:0, loss:0.06773385405540466
# torch.float32
# epoch:54, batch_id:1, loss:0.032232917845249176
# torch.float32
# epoch:54, batch_id:2, loss:0.013834396377205849
# torch.float32
# epoch:54, batch_id:3, loss:0.0027547709178179502
# torch.float32
# epoch:54, batch_id:4, loss:0.017251934856176376
# torch.float32
# epoch:54, batch_id:5, loss:0.0896882638335228
# torch.float32
# epoch:54, batch_id:6, loss:0.03966637700796127
# torch.float32
# epoch:54, batch_id:7, loss:0.25931161642074585
# torch.float32
# epoch:54, batch_id:8, loss:0.04899110272526741
# torch.float32
# epoch:54, batch_id:9, loss:0.0714418962597847
# torch.float32
# epoch:54, batch_id:10, loss:0.09096869081258774
# torch.float32
# epoch:54, batch_id:11, loss:0.1598784327507019
# torch.float32
# epoch:55, batch_id:0, loss:0.016216175630688667
# torch.float32
# epoch:55, batch_id:1, loss:0.010594864375889301
# torch.float32
# epoch:55, batch_id:2, loss:0.05899320915341377
# torch.float32
# epoch:55, batch_id:3, loss:0.32049280405044556
# torch.float32
# epoch:55, batch_id:4, loss:0.004851248115301132
# torch.float32
# epoch:55, batch_id:5, loss:0.004978395067155361
# torch.float32
# epoch:55, batch_id:6, loss:0.005574018694460392
# torch.float32
# epoch:55, batch_id:7, loss:0.18009305000305176
# torch.float32
# epoch:55, batch_id:8, loss:0.02976226434111595
# torch.float32
# epoch:55, batch_id:9, loss:0.013349604792892933
# torch.float32
# epoch:55, batch_id:10, loss:0.002670878078788519
# torch.float32
# epoch:55, batch_id:11, loss:0.27768760919570923
# torch.float32
# epoch:56, batch_id:0, loss:0.15960627794265747
# torch.float32
# epoch:56, batch_id:1, loss:0.05444498732686043
# torch.float32
# epoch:56, batch_id:2, loss:0.10616656392812729
# torch.float32
# epoch:56, batch_id:3, loss:0.06383170187473297
# torch.float32
# epoch:56, batch_id:4, loss:0.00900487881153822
# torch.float32
# epoch:56, batch_id:5, loss:0.04664965718984604
# torch.float32
# epoch:56, batch_id:6, loss:0.2870565950870514
# torch.float32
# epoch:56, batch_id:7, loss:0.022558072581887245
# torch.float32
# epoch:56, batch_id:8, loss:0.00411207415163517
# torch.float32
# epoch:56, batch_id:9, loss:0.06136972829699516
# torch.float32
# epoch:56, batch_id:10, loss:0.014489973895251751
# torch.float32
# epoch:56, batch_id:11, loss:0.09297998994588852
# torch.float32
# epoch:57, batch_id:0, loss:0.07492844015359879
# torch.float32
# epoch:57, batch_id:1, loss:0.017068110406398773
# torch.float32
# epoch:57, batch_id:2, loss:0.0558231845498085
# torch.float32
# epoch:57, batch_id:3, loss:0.03031543269753456
# torch.float32
# epoch:57, batch_id:4, loss:0.02419435791671276
# torch.float32
# epoch:57, batch_id:5, loss:0.2366345375776291
# torch.float32
# epoch:57, batch_id:6, loss:0.10474412143230438
# torch.float32
# epoch:57, batch_id:7, loss:0.0050393627025187016
# torch.float32
# epoch:57, batch_id:8, loss:0.024493543431162834
# torch.float32
# epoch:57, batch_id:9, loss:0.3995440602302551
# torch.float32
# epoch:57, batch_id:10, loss:0.012868653051555157
# torch.float32
# epoch:57, batch_id:11, loss:0.011022086255252361
# torch.float32
# epoch:58, batch_id:0, loss:0.2654513418674469
# torch.float32
# epoch:58, batch_id:1, loss:0.05693449452519417
# torch.float32
# epoch:58, batch_id:2, loss:0.010646125301718712
# torch.float32
# epoch:58, batch_id:3, loss:0.1971372812986374
# torch.float32
# epoch:58, batch_id:4, loss:0.2566990256309509
# torch.float32
# epoch:58, batch_id:5, loss:0.005747683811932802
# torch.float32
# epoch:58, batch_id:6, loss:0.021089140325784683
# torch.float32
# epoch:58, batch_id:7, loss:0.11801116168498993
# torch.float32
# epoch:58, batch_id:8, loss:0.05701468512415886
# torch.float32
# epoch:58, batch_id:9, loss:0.032441381365060806
# torch.float32
# epoch:58, batch_id:10, loss:0.01078740693628788
# torch.float32
# epoch:58, batch_id:11, loss:0.0044977362267673016
# torch.float32
# epoch:59, batch_id:0, loss:0.3048500418663025
# torch.float32
# epoch:59, batch_id:1, loss:0.3395116925239563
# torch.float32
# epoch:59, batch_id:2, loss:0.034551672637462616
# torch.float32
# epoch:59, batch_id:3, loss:0.04753734543919563
# torch.float32
# epoch:59, batch_id:4, loss:0.031686849892139435
# torch.float32
# epoch:59, batch_id:5, loss:0.013395257294178009
# torch.float32
# epoch:59, batch_id:6, loss:0.0014120747800916433
# torch.float32
# epoch:59, batch_id:7, loss:0.05485508590936661
# torch.float32
# epoch:59, batch_id:8, loss:0.010795253328979015
# torch.float32
# epoch:59, batch_id:9, loss:0.05326579138636589
# torch.float32
# epoch:59, batch_id:10, loss:0.008427519351243973
# torch.float32
# epoch:59, batch_id:11, loss:0.06747965514659882
# torch.float32
# epoch:60, batch_id:0, loss:0.003929489757865667
# torch.float32
# epoch:60, batch_id:1, loss:0.002679262775927782
# torch.float32
# epoch:60, batch_id:2, loss:0.03226535767316818
# torch.float32
# epoch:60, batch_id:3, loss:0.041819941252470016
# torch.float32
# epoch:60, batch_id:4, loss:0.03405597433447838
# torch.float32
# epoch:60, batch_id:5, loss:0.03315696492791176
# torch.float32
# epoch:60, batch_id:6, loss:0.24132120609283447
# torch.float32
# epoch:60, batch_id:7, loss:0.11962755024433136
# torch.float32
# epoch:60, batch_id:8, loss:0.011933849193155766
# torch.float32
# epoch:60, batch_id:9, loss:0.35814493894577026
# torch.float32
# epoch:60, batch_id:10, loss:0.021078387275338173
# torch.float32
# epoch:60, batch_id:11, loss:0.0028275037184357643
# torch.float32
# epoch:61, batch_id:0, loss:0.06664715707302094
# torch.float32
# epoch:61, batch_id:1, loss:0.03942079842090607
# torch.float32
# epoch:61, batch_id:2, loss:0.035455405712127686
# torch.float32
# epoch:61, batch_id:3, loss:0.03305388242006302
# torch.float32
# epoch:61, batch_id:4, loss:0.18735788762569427
# torch.float32
# epoch:61, batch_id:5, loss:0.06649965792894363
# torch.float32
# epoch:61, batch_id:6, loss:0.003537934273481369
# torch.float32
# epoch:61, batch_id:7, loss:0.017686326056718826
# torch.float32
# epoch:61, batch_id:8, loss:0.2634583115577698
# torch.float32
# epoch:61, batch_id:9, loss:0.17501093447208405
# torch.float32
# epoch:61, batch_id:10, loss:0.009915213100612164
# torch.float32
# epoch:61, batch_id:11, loss:0.010892610065639019
# torch.float32
# epoch:62, batch_id:0, loss:0.038814958184957504
# torch.float32
# epoch:62, batch_id:1, loss:0.014559006318449974
# torch.float32
# epoch:62, batch_id:2, loss:0.004196903668344021
# torch.float32
# epoch:62, batch_id:3, loss:0.21636417508125305
# torch.float32
# epoch:62, batch_id:4, loss:0.029505586251616478
# torch.float32
# epoch:62, batch_id:5, loss:0.005096382461488247
# torch.float32
# epoch:62, batch_id:6, loss:0.3636138439178467
# torch.float32
# epoch:62, batch_id:7, loss:0.005524816457182169
# torch.float32
# epoch:62, batch_id:8, loss:0.06847120821475983
# torch.float32
# epoch:62, batch_id:9, loss:0.14586378633975983
# torch.float32
# epoch:62, batch_id:10, loss:0.017624277621507645
# torch.float32
# epoch:62, batch_id:11, loss:0.008756684139370918
# torch.float32
# epoch:63, batch_id:0, loss:0.08670805394649506
# torch.float32
# epoch:63, batch_id:1, loss:0.07408203184604645
# torch.float32
# epoch:63, batch_id:2, loss:0.008352172560989857
# torch.float32
# epoch:63, batch_id:3, loss:0.2717825472354889
# torch.float32
# epoch:63, batch_id:4, loss:0.003224557265639305
# torch.float32
# epoch:63, batch_id:5, loss:0.009057221002876759
# torch.float32
# epoch:63, batch_id:6, loss:0.0034094764851033688
# torch.float32
# epoch:63, batch_id:7, loss:0.0223025344312191
# torch.float32
# epoch:63, batch_id:8, loss:0.11412601172924042
# torch.float32
# epoch:63, batch_id:9, loss:0.03980353847146034
# torch.float32
# epoch:63, batch_id:10, loss:0.17429976165294647
# torch.float32
# epoch:63, batch_id:11, loss:0.09733018279075623
# torch.float32
# epoch:64, batch_id:0, loss:0.0047407811507582664
# torch.float32
# epoch:64, batch_id:1, loss:0.012954821810126305
# torch.float32
# epoch:64, batch_id:2, loss:0.03857842832803726
# torch.float32
# epoch:64, batch_id:3, loss:0.04341471940279007
# torch.float32
# epoch:64, batch_id:4, loss:0.09946517646312714
# torch.float32
# epoch:64, batch_id:5, loss:0.002889444585889578
# torch.float32
# epoch:64, batch_id:6, loss:0.05339750647544861
# torch.float32
# epoch:64, batch_id:7, loss:0.23038950562477112
# torch.float32
# epoch:64, batch_id:8, loss:0.006351684685796499
# torch.float32
# epoch:64, batch_id:9, loss:0.005509620066732168
# torch.float32
# epoch:64, batch_id:10, loss:0.3810270130634308
# torch.float32
# epoch:64, batch_id:11, loss:0.012906000018119812
# torch.float32
# epoch:65, batch_id:0, loss:0.06771717220544815
# torch.float32
# epoch:65, batch_id:1, loss:0.015956899151206017
# torch.float32
# epoch:65, batch_id:2, loss:0.036806393414735794
# torch.float32
# epoch:65, batch_id:3, loss:0.008408406749367714
# torch.float32
# epoch:65, batch_id:4, loss:0.003680417314171791
# torch.float32
# epoch:65, batch_id:5, loss:0.051105160266160965
# torch.float32
# epoch:65, batch_id:6, loss:0.12599921226501465
# torch.float32
# epoch:65, batch_id:7, loss:0.2615372836589813
# ...
# epoch:78, batch_id:4, loss:0.09029079973697662
# torch.float32
# epoch:78, batch_id:5, loss:0.0035997226368635893
# torch.float32
# epoch:78, batch_id:6, loss:0.08065090328454971
# torch.float32
# epoch:78, batch_id:7, loss:0.01531172264367342
# torch.float32
# epoch:78, batch_id:8, loss:0.00039026825106702745
# torch.float32
# epoch:78, batch_id:9, loss:0.23200269043445587
# torch.float32
# epoch:78, batch_id:10, loss:0.002819254994392395
# torch.float32
# epoch:78, batch_id:11, loss:0.09276631474494934
# torch.float32
# epoch:79, batch_id:0, loss:0.18686121702194214
# torch.float32
# epoch:79, batch_id:1, loss:0.022531870752573013
# torch.float32
# epoch:79, batch_id:2, loss:0.07647906243801117
# torch.float32
# epoch:79, batch_id:3, loss:0.04229736328125
# torch.float32
# epoch:79, batch_id:4, loss:0.060051947832107544
# torch.float32
# epoch:79, batch_id:5, loss:0.0011033655609935522
# torch.float32
# epoch:79, batch_id:6, loss:0.0025419879239052534
# torch.float32
# epoch:79, batch_id:7, loss:0.019506918266415596
# torch.float32
# epoch:79, batch_id:8, loss:0.006004492752254009
# torch.float32
# epoch:79, batch_id:9, loss:0.025393839925527573
# torch.float32
# epoch:79, batch_id:10, loss:0.006302339490503073
# torch.float32
# epoch:79, batch_id:11, loss:0.4198566973209381
# torch.float32
# epoch:80, batch_id:0, loss:0.02210111916065216
# torch.float32
# epoch:80, batch_id:1, loss:0.22235175967216492
# torch.float32
# epoch:80, batch_id:2, loss:0.0870155319571495
# torch.float32
# epoch:80, batch_id:3, loss:0.06641368567943573
# torch.float32
# epoch:80, batch_id:4, loss:0.0019905208609998226
# torch.float32
# epoch:80, batch_id:5, loss:0.040616199374198914
# torch.float32
# epoch:80, batch_id:6, loss:0.18409179151058197
# torch.float32
# epoch:80, batch_id:7, loss:0.2063610553741455
# torch.float32
# epoch:80, batch_id:8, loss:0.07185450196266174
# torch.float32
# epoch:80, batch_id:9, loss:0.02719016745686531
# torch.float32
# epoch:80, batch_id:10, loss:0.0012970215175300837
# torch.float32
# epoch:80, batch_id:11, loss:0.07920784503221512
# torch.float32
# epoch:81, batch_id:0, loss:0.015418848022818565
# torch.float32
# epoch:81, batch_id:1, loss:0.005316113121807575
# torch.float32
# epoch:81, batch_id:2, loss:0.0004335121193435043
# torch.float32
# epoch:81, batch_id:3, loss:0.1059727668762207
# torch.float32
# epoch:81, batch_id:4, loss:0.30578893423080444
# torch.float32
# epoch:81, batch_id:5, loss:0.024297120049595833
# torch.float32
# epoch:81, batch_id:6, loss:0.005310457199811935
# torch.float32
# epoch:81, batch_id:7, loss:0.0028873332776129246
# torch.float32
# epoch:81, batch_id:8, loss:0.16830690205097198
# torch.float32
# epoch:81, batch_id:9, loss:0.03207676485180855
# torch.float32
# epoch:81, batch_id:10, loss:0.06899933516979218
# torch.float32
# epoch:81, batch_id:11, loss:0.06185600906610489
# torch.float32
# epoch:82, batch_id:0, loss:0.07974202930927277
# torch.float32
# epoch:82, batch_id:1, loss:0.0071660540997982025
# torch.float32
# epoch:82, batch_id:2, loss:0.023037048056721687
# torch.float32
# epoch:82, batch_id:3, loss:0.028370719403028488
# torch.float32
# epoch:82, batch_id:4, loss:0.09965549409389496
# torch.float32
# epoch:82, batch_id:5, loss:0.004053574986755848
# torch.float32
# epoch:82, batch_id:6, loss:0.0020105871371924877
# torch.float32
# epoch:82, batch_id:7, loss:0.23028042912483215
# torch.float32
# epoch:82, batch_id:8, loss:0.3889354169368744
# torch.float32
# epoch:82, batch_id:9, loss:0.018746837973594666
# torch.float32
# epoch:82, batch_id:10, loss:0.060540296137332916
# torch.float32
# epoch:82, batch_id:11, loss:0.0024535558186471462
# torch.float32
# epoch:83, batch_id:0, loss:0.0022691902704536915
# torch.float32
# epoch:83, batch_id:1, loss:0.10579965263605118
# torch.float32
# epoch:83, batch_id:2, loss:0.0172662902623415
# torch.float32
# epoch:83, batch_id:3, loss:0.09654839336872101
# torch.float32
# epoch:83, batch_id:4, loss:0.005797439254820347
# torch.float32
# epoch:83, batch_id:5, loss:0.11916466057300568
# torch.float32
# epoch:83, batch_id:6, loss:0.028455253690481186
# torch.float32
# epoch:83, batch_id:7, loss:0.08100861310958862
# torch.float32
# epoch:83, batch_id:8, loss:0.008041574619710445
# torch.float32
# epoch:83, batch_id:9, loss:0.10197190195322037
# torch.float32
# epoch:83, batch_id:10, loss:0.3155566453933716
# torch.float32
# epoch:83, batch_id:11, loss:0.002593758050352335
# torch.float32
# epoch:84, batch_id:0, loss:0.1337183713912964
# torch.float32
# epoch:84, batch_id:1, loss:0.023944072425365448
# torch.float32
# epoch:84, batch_id:2, loss:0.05184360593557358
# torch.float32
# epoch:84, batch_id:3, loss:0.024290723726153374
# torch.float32
# epoch:84, batch_id:4, loss:0.04649483785033226
# torch.float32
# epoch:84, batch_id:5, loss:0.06523601710796356
# torch.float32
# epoch:84, batch_id:6, loss:0.01690841093659401
# torch.float32
# epoch:84, batch_id:7, loss:0.011574702337384224
# torch.float32
# epoch:84, batch_id:8, loss:0.10715945810079575
# torch.float32
# epoch:84, batch_id:9, loss:0.021697375923395157
# torch.float32
# epoch:84, batch_id:10, loss:0.34544116258621216
# torch.float32
# epoch:84, batch_id:11, loss:0.031634729355573654
# torch.float32
# epoch:85, batch_id:0, loss:0.03700520843267441
# torch.float32
# epoch:85, batch_id:1, loss:0.053569816052913666
# torch.float32
# epoch:85, batch_id:2, loss:0.043630242347717285
# torch.float32
# epoch:85, batch_id:3, loss:0.14046421647071838
# torch.float32
# epoch:85, batch_id:4, loss:0.03900700435042381
# torch.float32
# epoch:85, batch_id:5, loss:0.0025033808778971434
# torch.float32
# epoch:85, batch_id:6, loss:0.08396849036216736
# torch.float32
# epoch:85, batch_id:7, loss:0.3194466829299927
# torch.float32
# epoch:85, batch_id:8, loss:0.09090521931648254
# torch.float32
# epoch:85, batch_id:9, loss:0.0025223190896213055
# torch.float32
# epoch:85, batch_id:10, loss:0.00282563385553658
# torch.float32
# epoch:85, batch_id:11, loss:0.006940203718841076
# torch.float32
# epoch:86, batch_id:0, loss:0.012184416875243187
# torch.float32
# epoch:86, batch_id:1, loss:0.02695350907742977
# torch.float32
# epoch:86, batch_id:2, loss:0.05326516553759575
# torch.float32
# epoch:86, batch_id:3, loss:0.04564657434821129
# torch.float32
# epoch:86, batch_id:4, loss:0.019886339083313942
# torch.float32
# epoch:86, batch_id:5, loss:0.3651372790336609
# torch.float32
# epoch:86, batch_id:6, loss:0.09554606676101685
# torch.float32
# epoch:86, batch_id:7, loss:0.017452873289585114
# torch.float32
# epoch:86, batch_id:8, loss:0.0028677680529654026
# torch.float32
# epoch:86, batch_id:9, loss:0.18623049557209015
# torch.float32
# epoch:86, batch_id:10, loss:0.0057576559484004974
# torch.float32
# epoch:86, batch_id:11, loss:0.07782270759344101
# torch.float32
# epoch:87, batch_id:0, loss:0.08160963654518127
# torch.float32
# epoch:87, batch_id:1, loss:0.01106199063360691
# torch.float32
# epoch:87, batch_id:2, loss:0.01868152618408203
# torch.float32
# epoch:87, batch_id:3, loss:0.011013459414243698
# torch.float32
# epoch:87, batch_id:4, loss:0.05087294057011604
# torch.float32
# epoch:87, batch_id:5, loss:0.07267193496227264
# torch.float32
# epoch:87, batch_id:6, loss:0.007576151750981808
# torch.float32
# epoch:87, batch_id:7, loss:0.009611168876290321
# torch.float32
# epoch:87, batch_id:8, loss:0.02361445501446724
# torch.float32
# epoch:87, batch_id:9, loss:0.009704986587166786
# torch.float32
# epoch:87, batch_id:10, loss:0.21867355704307556
# torch.float32
# epoch:87, batch_id:11, loss:0.3150476813316345
# torch.float32
# epoch:88, batch_id:0, loss:0.006871143821626902
# torch.float32
# epoch:88, batch_id:1, loss:0.02059794031083584
# torch.float32
# epoch:88, batch_id:2, loss:0.14662377536296844
# torch.float32
# epoch:88, batch_id:3, loss:0.03958277404308319
# torch.float32
# epoch:88, batch_id:4, loss:0.2058899849653244
# torch.float32
# epoch:88, batch_id:5, loss:0.2866445779800415
# torch.float32
# epoch:88, batch_id:6, loss:0.004143188241869211
# torch.float32
# epoch:88, batch_id:7, loss:0.00097941467538476
# torch.float32
# epoch:88, batch_id:8, loss:0.0026950142346322536
# torch.float32
# epoch:88, batch_id:9, loss:0.0036982421297580004
# torch.float32
# epoch:88, batch_id:10, loss:0.0035198789555579424
# torch.float32
# epoch:88, batch_id:11, loss:0.08128564804792404
# torch.float32
# epoch:89, batch_id:0, loss:0.2137695550918579
# torch.float32
# epoch:89, batch_id:1, loss:0.08828619122505188
# torch.float32
# epoch:89, batch_id:2, loss:0.006450814660638571
# torch.float32
# epoch:89, batch_id:3, loss:0.062027376145124435
# torch.float32
# epoch:89, batch_id:4, loss:0.002626853995025158
# torch.float32
# epoch:89, batch_id:5, loss:0.05203815549612045
# torch.float32
# epoch:89, batch_id:6, loss:0.007860480807721615
# torch.float32
# epoch:89, batch_id:7, loss:0.09684351831674576
# torch.float32
# epoch:89, batch_id:8, loss:0.0819426104426384
# torch.float32
# epoch:89, batch_id:9, loss:0.004006767179816961
# torch.float32
# epoch:89, batch_id:10, loss:0.1754460632801056
# torch.float32
# epoch:89, batch_id:11, loss:0.01796097680926323
# torch.float32
# epoch:90, batch_id:0, loss:0.04194267466664314
# torch.float32
# epoch:90, batch_id:1, loss:0.18974196910858154
# torch.float32
# epoch:90, batch_id:2, loss:0.006590359844267368
# torch.float32
# epoch:90, batch_id:3, loss:0.004591455217450857
# torch.float32
# epoch:90, batch_id:4, loss:0.09766850620508194
# torch.float32
# epoch:90, batch_id:5, loss:0.2848750948905945
# torch.float32
# epoch:90, batch_id:6, loss:0.013926587998867035
# torch.float32
# epoch:90, batch_id:7, loss:0.003202219260856509
# torch.float32
# epoch:90, batch_id:8, loss:0.12992629408836365
# torch.float32
# epoch:90, batch_id:9, loss:0.004591094795614481
# torch.float32
# epoch:90, batch_id:10, loss:0.02914155088365078
# torch.float32
# epoch:90, batch_id:11, loss:0.3244780898094177
# torch.float32
# epoch:91, batch_id:0, loss:0.015354973264038563
# torch.float32
# epoch:91, batch_id:1, loss:0.014025719836354256
# torch.float32
# epoch:91, batch_id:2, loss:0.0261678583920002
# torch.float32
# epoch:91, batch_id:3, loss:0.016979867592453957
# torch.float32
# epoch:91, batch_id:4, loss:0.018050627782940865
# torch.float32
# epoch:91, batch_id:5, loss:0.21693618595600128
# torch.float32
# epoch:91, batch_id:6, loss:0.0026853708550333977
# torch.float32
# epoch:91, batch_id:7, loss:0.41257229447364807
# torch.float32
# epoch:91, batch_id:8, loss:0.01397249661386013
# torch.float32
# epoch:91, batch_id:9, loss:0.21241550147533417
# torch.float32
# epoch:91, batch_id:10, loss:0.05091847851872444
# torch.float32
# epoch:91, batch_id:11, loss:0.04976183921098709
# torch.float32
# epoch:92, batch_id:0, loss:0.0033626470249146223
# torch.float32
# epoch:92, batch_id:1, loss:0.11212901026010513
# torch.float32
# epoch:92, batch_id:2, loss:0.002345710527151823
# torch.float32
# epoch:92, batch_id:3, loss:0.05499562621116638
# torch.float32
# epoch:92, batch_id:4, loss:0.007355701178312302
# torch.float32
# epoch:92, batch_id:5, loss:0.006021917797625065
# torch.float32
# epoch:92, batch_id:6, loss:0.07168631255626678
# torch.float32
# epoch:92, batch_id:7, loss:0.010443566367030144
# torch.float32
# epoch:92, batch_id:8, loss:0.0005162045126780868
# torch.float32
# epoch:92, batch_id:9, loss:0.18092459440231323
# torch.float32
# epoch:92, batch_id:10, loss:0.009132137522101402
# torch.float32
# epoch:92, batch_id:11, loss:0.3064204454421997
# torch.float32
# epoch:93, batch_id:0, loss:0.04824671894311905
# torch.float32
# epoch:93, batch_id:1, loss:0.010457774624228477
# torch.float32
# epoch:93, batch_id:2, loss:0.061972726136446
# torch.float32
# epoch:93, batch_id:3, loss:0.03486325591802597
# torch.float32
# epoch:93, batch_id:4, loss:0.0013791549718007445
# torch.float32
# epoch:93, batch_id:5, loss:0.011358238756656647
# torch.float32
# epoch:93, batch_id:6, loss:0.08598554879426956
# torch.float32
# epoch:93, batch_id:7, loss:0.002419488737359643
# torch.float32
# epoch:93, batch_id:8, loss:0.07330930978059769
# torch.float32
# epoch:93, batch_id:9, loss:0.0659748837351799
# torch.float32
# epoch:93, batch_id:10, loss:0.15739330649375916
# torch.float32
# epoch:93, batch_id:11, loss:0.3488905727863312
# torch.float32
# epoch:94, batch_id:0, loss:0.07763612270355225
# torch.float32
# epoch:94, batch_id:1, loss:0.06107603386044502
# torch.float32
# epoch:94, batch_id:2, loss:0.0026184667367488146
# torch.float32
# epoch:94, batch_id:3, loss:0.012070052325725555
# torch.float32
# epoch:94, batch_id:4, loss:0.033781953155994415
# torch.float32
# epoch:94, batch_id:5, loss:0.0014216008130460978
# torch.float32
# epoch:94, batch_id:6, loss:0.06237945705652237
# torch.float32
# epoch:94, batch_id:7, loss:0.050120770931243896
# torch.float32
# epoch:94, batch_id:8, loss:0.050696663558483124
# torch.float32
# epoch:94, batch_id:9, loss:0.005452909506857395
# torch.float32
# epoch:94, batch_id:10, loss:0.3269795775413513
# torch.float32
# epoch:94, batch_id:11, loss:0.15425555408000946
# torch.float32
# epoch:95, batch_id:0, loss:0.28463101387023926
# torch.float32
# epoch:95, batch_id:1, loss:0.04613598808646202
# torch.float32
# epoch:95, batch_id:2, loss:0.015494244173169136
# torch.float32
# epoch:95, batch_id:3, loss:0.004651993978768587
# torch.float32
# epoch:95, batch_id:4, loss:0.03093000315129757
# torch.float32
# epoch:95, batch_id:5, loss:0.0009561438346281648
# torch.float32
# epoch:95, batch_id:6, loss:0.007782988250255585
# torch.float32
# epoch:95, batch_id:7, loss:0.02700287103652954
# torch.float32
# epoch:95, batch_id:8, loss:0.0325092151761055
# torch.float32
# epoch:95, batch_id:9, loss:0.2664380669593811
# torch.float32
# epoch:95, batch_id:10, loss:0.25206953287124634
# torch.float32
# epoch:95, batch_id:11, loss:0.1378045678138733
# torch.float32
# epoch:96, batch_id:0, loss:0.027813419699668884
# torch.float32
# epoch:96, batch_id:1, loss:0.32223382592201233
# torch.float32
# epoch:96, batch_id:2, loss:0.0011410434963181615
# torch.float32
# epoch:96, batch_id:3, loss:0.045761920511722565
# torch.float32
# epoch:96, batch_id:4, loss:0.01139915268868208
# torch.float32
# epoch:96, batch_id:5, loss:0.012845245189964771
# torch.float32
# epoch:96, batch_id:6, loss:0.30252015590667725
# torch.float32
# epoch:96, batch_id:7, loss:0.02949858270585537
# torch.float32
# epoch:96, batch_id:8, loss:0.31510335206985474
# torch.float32
# epoch:96, batch_id:9, loss:0.03116743639111519
# torch.float32
# epoch:96, batch_id:10, loss:0.012303256429731846
# torch.float32
# epoch:96, batch_id:11, loss:0.010112409479916096
# torch.float32
# epoch:97, batch_id:0, loss:0.03652578964829445
# torch.float32
# epoch:97, batch_id:1, loss:0.05339907854795456
# torch.float32
# epoch:97, batch_id:2, loss:0.011023853905498981
# torch.float32
# epoch:97, batch_id:3, loss:0.013614279218018055
# torch.float32
# epoch:97, batch_id:4, loss:0.004084621090441942
# torch.float32
# epoch:97, batch_id:5, loss:0.22306029498577118
# torch.float32
# epoch:97, batch_id:6, loss:0.14353927969932556
# torch.float32
# epoch:97, batch_id:7, loss:0.17785340547561646
# torch.float32
# epoch:97, batch_id:8, loss:0.1654900312423706
# torch.float32
# epoch:97, batch_id:9, loss:0.16844618320465088
# torch.float32
# epoch:97, batch_id:10, loss:0.21350185573101044
# torch.float32
# epoch:97, batch_id:11, loss:0.00625468697398901
# torch.float32
# epoch:98, batch_id:0, loss:0.09729015082120895
# torch.float32
# epoch:98, batch_id:1, loss:0.017433129251003265
# torch.float32
# epoch:98, batch_id:2, loss:0.003266435582190752
# torch.float32
# epoch:98, batch_id:3, loss:0.028591057285666466
# torch.float32
# epoch:98, batch_id:4, loss:0.06213143467903137
# torch.float32
# epoch:98, batch_id:5, loss:0.0590507909655571
# torch.float32
# epoch:98, batch_id:6, loss:0.011033125221729279
# torch.float32
# epoch:98, batch_id:7, loss:0.9499222040176392
# torch.float32
# epoch:98, batch_id:8, loss:0.2939978241920471
# torch.float32
# epoch:98, batch_id:9, loss:0.007704123854637146
# torch.float32
# epoch:98, batch_id:10, loss:0.009217943996191025
# torch.float32
# epoch:98, batch_id:11, loss:0.01308218389749527
# torch.float32
# epoch:99, batch_id:0, loss:0.3367733657360077
# torch.float32
# epoch:99, batch_id:1, loss:0.009480996988713741
# torch.float32
# epoch:99, batch_id:2, loss:0.011667525395751
# torch.float32
# epoch:99, batch_id:3, loss:0.0033657527528703213
# torch.float32
# epoch:99, batch_id:4, loss:0.019347433000802994
# torch.float32
# epoch:99, batch_id:5, loss:0.007514572236686945
# torch.float32
# epoch:99, batch_id:6, loss:0.04218054562807083
# torch.float32
# epoch:99, batch_id:7, loss:0.008326927199959755
# torch.float32
# epoch:99, batch_id:8, loss:0.5805743932723999
# torch.float32
# epoch:99, batch_id:9, loss:0.0009550123359076679
# torch.float32
# epoch:99, batch_id:10, loss:0.15436191856861115
# torch.float32
# epoch:99, batch_id:11, loss:0.15195298194885254

# %%
net.eval()
prob_func = nn.Softmax(dim=1)
# x = torch.rand((4, 3))
# x = prob_func(x)
# print(x)
# print(torch.argmax(x,dim=1))
with torch.no_grad():

    for epoch in range(EPOCH):
        num_cnt = 0
        for batch_id, (Sample_data, labels) in enumerate(test_loader):
            total = Sample_data.shape[0]
            pred = net(Sample_data)
            pred = prob_func(pred)
            idx = torch.argmax(pred,dim=1)
            for index in range(total):
                if idx[index] == labels[index]:
                    num_cnt += 1

            acc = num_cnt / total
            num_cnt = 0
            print(f"epoch:{epoch}, batch_id:{batch_id}, acc:{acc}")
# Out:
# epoch:0, batch_id:0, acc:1.0
# epoch:0, batch_id:1, acc:1.0
# epoch:0, batch_id:2, acc:1.0
# epoch:1, batch_id:0, acc:1.0
# epoch:1, batch_id:1, acc:1.0
# epoch:1, batch_id:2, acc:1.0
# epoch:2, batch_id:0, acc:1.0
# epoch:2, batch_id:1, acc:1.0
# epoch:2, batch_id:2, acc:1.0
# epoch:3, batch_id:0, acc:1.0
# epoch:3, batch_id:1, acc:1.0
# epoch:3, batch_id:2, acc:1.0
# epoch:4, batch_id:0, acc:1.0
# epoch:4, batch_id:1, acc:1.0
# epoch:4, batch_id:2, acc:1.0
# epoch:5, batch_id:0, acc:1.0
# epoch:5, batch_id:1, acc:1.0
# epoch:5, batch_id:2, acc:1.0
# epoch:6, batch_id:0, acc:1.0
# epoch:6, batch_id:1, acc:1.0
# epoch:6, batch_id:2, acc:1.0
# epoch:7, batch_id:0, acc:1.0
# epoch:7, batch_id:1, acc:1.0
# epoch:7, batch_id:2, acc:1.0
# epoch:8, batch_id:0, acc:1.0
# epoch:8, batch_id:1, acc:1.0
# epoch:8, batch_id:2, acc:1.0
# epoch:9, batch_id:0, acc:1.0
# epoch:9, batch_id:1, acc:1.0
# epoch:9, batch_id:2, acc:1.0
# epoch:10, batch_id:0, acc:1.0
# epoch:10, batch_id:1, acc:1.0
# epoch:10, batch_id:2, acc:1.0
# epoch:11, batch_id:0, acc:1.0
# epoch:11, batch_id:1, acc:1.0
# epoch:11, batch_id:2, acc:1.0
# epoch:12, batch_id:0, acc:1.0
# epoch:12, batch_id:1, acc:1.0
# epoch:12, batch_id:2, acc:1.0
# epoch:13, batch_id:0, acc:1.0
# epoch:13, batch_id:1, acc:1.0
# epoch:13, batch_id:2, acc:1.0
# epoch:14, batch_id:0, acc:1.0
# epoch:14, batch_id:1, acc:1.0
# epoch:14, batch_id:2, acc:1.0
# epoch:15, batch_id:0, acc:1.0
# epoch:15, batch_id:1, acc:1.0
# epoch:15, batch_id:2, acc:1.0
# epoch:16, batch_id:0, acc:1.0
# epoch:16, batch_id:1, acc:1.0
# epoch:16, batch_id:2, acc:1.0
# epoch:17, batch_id:0, acc:1.0
# epoch:17, batch_id:1, acc:1.0
# epoch:17, batch_id:2, acc:1.0
# epoch:18, batch_id:0, acc:1.0
# epoch:18, batch_id:1, acc:1.0
# epoch:18, batch_id:2, acc:1.0
# epoch:19, batch_id:0, acc:1.0
# epoch:19, batch_id:1, acc:1.0
# epoch:19, batch_id:2, acc:1.0
# epoch:20, batch_id:0, acc:1.0
# epoch:20, batch_id:1, acc:1.0
# epoch:20, batch_id:2, acc:1.0
# epoch:21, batch_id:0, acc:1.0
# epoch:21, batch_id:1, acc:1.0
# epoch:21, batch_id:2, acc:1.0
# epoch:22, batch_id:0, acc:1.0
# epoch:22, batch_id:1, acc:1.0
# epoch:22, batch_id:2, acc:1.0
# epoch:23, batch_id:0, acc:1.0
# epoch:23, batch_id:1, acc:1.0
# epoch:23, batch_id:2, acc:1.0
# epoch:24, batch_id:0, acc:1.0
# epoch:24, batch_id:1, acc:1.0
# epoch:24, batch_id:2, acc:1.0
# epoch:25, batch_id:0, acc:1.0
# epoch:25, batch_id:1, acc:1.0
# epoch:25, batch_id:2, acc:1.0
# epoch:26, batch_id:0, acc:1.0
# epoch:26, batch_id:1, acc:1.0
# epoch:26, batch_id:2, acc:1.0
# epoch:27, batch_id:0, acc:1.0
# epoch:27, batch_id:1, acc:1.0
# epoch:27, batch_id:2, acc:1.0
# epoch:28, batch_id:0, acc:1.0
# epoch:28, batch_id:1, acc:1.0
# epoch:28, batch_id:2, acc:1.0
# epoch:29, batch_id:0, acc:1.0
# epoch:29, batch_id:1, acc:1.0
# epoch:29, batch_id:2, acc:1.0
# epoch:30, batch_id:0, acc:1.0
# epoch:30, batch_id:1, acc:1.0
# epoch:30, batch_id:2, acc:1.0
# epoch:31, batch_id:0, acc:1.0
# epoch:31, batch_id:1, acc:1.0
# epoch:31, batch_id:2, acc:1.0
# epoch:32, batch_id:0, acc:1.0
# epoch:32, batch_id:1, acc:1.0
# epoch:32, batch_id:2, acc:1.0
# epoch:33, batch_id:0, acc:1.0
# epoch:33, batch_id:1, acc:1.0
# epoch:33, batch_id:2, acc:1.0
# epoch:34, batch_id:0, acc:1.0
# epoch:34, batch_id:1, acc:1.0
# epoch:34, batch_id:2, acc:1.0
# epoch:35, batch_id:0, acc:1.0
# epoch:35, batch_id:1, acc:1.0
# epoch:35, batch_id:2, acc:1.0
# epoch:36, batch_id:0, acc:1.0
# epoch:36, batch_id:1, acc:1.0
# epoch:36, batch_id:2, acc:1.0
# epoch:37, batch_id:0, acc:1.0
# epoch:37, batch_id:1, acc:1.0
# epoch:37, batch_id:2, acc:1.0
# epoch:38, batch_id:0, acc:1.0
# epoch:38, batch_id:1, acc:1.0
# epoch:38, batch_id:2, acc:1.0
# epoch:39, batch_id:0, acc:1.0
# epoch:39, batch_id:1, acc:1.0
# epoch:39, batch_id:2, acc:1.0
# epoch:40, batch_id:0, acc:1.0
# epoch:40, batch_id:1, acc:1.0
# epoch:40, batch_id:2, acc:1.0
# epoch:41, batch_id:0, acc:1.0
# epoch:41, batch_id:1, acc:1.0
# epoch:41, batch_id:2, acc:1.0
# epoch:42, batch_id:0, acc:1.0
# epoch:42, batch_id:1, acc:1.0
# epoch:42, batch_id:2, acc:1.0
# epoch:43, batch_id:0, acc:1.0
# epoch:43, batch_id:1, acc:1.0
# epoch:43, batch_id:2, acc:1.0
# epoch:44, batch_id:0, acc:1.0
# epoch:44, batch_id:1, acc:1.0
# epoch:44, batch_id:2, acc:1.0
# epoch:45, batch_id:0, acc:1.0
# epoch:45, batch_id:1, acc:1.0
# epoch:45, batch_id:2, acc:1.0
# epoch:46, batch_id:0, acc:1.0
# epoch:46, batch_id:1, acc:1.0
# epoch:46, batch_id:2, acc:1.0
# epoch:47, batch_id:0, acc:1.0
# epoch:47, batch_id:1, acc:1.0
# epoch:47, batch_id:2, acc:1.0
# epoch:48, batch_id:0, acc:1.0
# epoch:48, batch_id:1, acc:1.0
# epoch:48, batch_id:2, acc:1.0
# epoch:49, batch_id:0, acc:1.0
# epoch:49, batch_id:1, acc:1.0
# epoch:49, batch_id:2, acc:1.0
# epoch:50, batch_id:0, acc:1.0
# epoch:50, batch_id:1, acc:1.0
# epoch:50, batch_id:2, acc:1.0
# epoch:51, batch_id:0, acc:1.0
# epoch:51, batch_id:1, acc:1.0
# epoch:51, batch_id:2, acc:1.0
# epoch:52, batch_id:0, acc:1.0
# epoch:52, batch_id:1, acc:1.0
# epoch:52, batch_id:2, acc:1.0
# epoch:53, batch_id:0, acc:1.0
# epoch:53, batch_id:1, acc:1.0
# epoch:53, batch_id:2, acc:1.0
# epoch:54, batch_id:0, acc:1.0
# epoch:54, batch_id:1, acc:1.0
# epoch:54, batch_id:2, acc:1.0
# epoch:55, batch_id:0, acc:1.0
# epoch:55, batch_id:1, acc:1.0
# epoch:55, batch_id:2, acc:1.0
# epoch:56, batch_id:0, acc:1.0
# epoch:56, batch_id:1, acc:1.0
# epoch:56, batch_id:2, acc:1.0
# epoch:57, batch_id:0, acc:1.0
# epoch:57, batch_id:1, acc:1.0
# epoch:57, batch_id:2, acc:1.0
# epoch:58, batch_id:0, acc:1.0
# epoch:58, batch_id:1, acc:1.0
# epoch:58, batch_id:2, acc:1.0
# epoch:59, batch_id:0, acc:1.0
# epoch:59, batch_id:1, acc:1.0
# epoch:59, batch_id:2, acc:1.0
# epoch:60, batch_id:0, acc:1.0
# epoch:60, batch_id:1, acc:1.0
# epoch:60, batch_id:2, acc:1.0
# epoch:61, batch_id:0, acc:1.0
# epoch:61, batch_id:1, acc:1.0
# epoch:61, batch_id:2, acc:1.0
# epoch:62, batch_id:0, acc:1.0
# epoch:62, batch_id:1, acc:1.0
# epoch:62, batch_id:2, acc:1.0
# epoch:63, batch_id:0, acc:1.0
# epoch:63, batch_id:1, acc:1.0
# epoch:63, batch_id:2, acc:1.0
# epoch:64, batch_id:0, acc:1.0
# epoch:64, batch_id:1, acc:1.0
# epoch:64, batch_id:2, acc:1.0
# epoch:65, batch_id:0, acc:1.0
# epoch:65, batch_id:1, acc:1.0
# epoch:65, batch_id:2, acc:1.0
# epoch:66, batch_id:0, acc:1.0
# epoch:66, batch_id:1, acc:1.0
# epoch:66, batch_id:2, acc:1.0
# epoch:67, batch_id:0, acc:1.0
# epoch:67, batch_id:1, acc:1.0
# epoch:67, batch_id:2, acc:1.0
# epoch:68, batch_id:0, acc:1.0
# epoch:68, batch_id:1, acc:1.0
# epoch:68, batch_id:2, acc:1.0
# epoch:69, batch_id:0, acc:1.0
# epoch:69, batch_id:1, acc:1.0
# epoch:69, batch_id:2, acc:1.0
# epoch:70, batch_id:0, acc:1.0
# epoch:70, batch_id:1, acc:1.0
# epoch:70, batch_id:2, acc:1.0
# epoch:71, batch_id:0, acc:1.0
# epoch:71, batch_id:1, acc:1.0
# epoch:71, batch_id:2, acc:1.0
# epoch:72, batch_id:0, acc:1.0
# epoch:72, batch_id:1, acc:1.0
# epoch:72, batch_id:2, acc:1.0
# epoch:73, batch_id:0, acc:1.0
# epoch:73, batch_id:1, acc:1.0
# epoch:73, batch_id:2, acc:1.0
# epoch:74, batch_id:0, acc:1.0
# epoch:74, batch_id:1, acc:1.0
# epoch:74, batch_id:2, acc:1.0
# epoch:75, batch_id:0, acc:1.0
# epoch:75, batch_id:1, acc:1.0
# epoch:75, batch_id:2, acc:1.0
# epoch:76, batch_id:0, acc:1.0
# epoch:76, batch_id:1, acc:1.0
# epoch:76, batch_id:2, acc:1.0
# epoch:77, batch_id:0, acc:1.0
# epoch:77, batch_id:1, acc:1.0
# epoch:77, batch_id:2, acc:1.0
# epoch:78, batch_id:0, acc:1.0
# epoch:78, batch_id:1, acc:1.0
# epoch:78, batch_id:2, acc:1.0
# epoch:79, batch_id:0, acc:1.0
# epoch:79, batch_id:1, acc:1.0
# epoch:79, batch_id:2, acc:1.0
# epoch:80, batch_id:0, acc:1.0
# epoch:80, batch_id:1, acc:1.0
# epoch:80, batch_id:2, acc:1.0
# epoch:81, batch_id:0, acc:1.0
# epoch:81, batch_id:1, acc:1.0
# epoch:81, batch_id:2, acc:1.0
# epoch:82, batch_id:0, acc:1.0
# epoch:82, batch_id:1, acc:1.0
# epoch:82, batch_id:2, acc:1.0
# epoch:83, batch_id:0, acc:1.0
# epoch:83, batch_id:1, acc:1.0
# epoch:83, batch_id:2, acc:1.0
# epoch:84, batch_id:0, acc:1.0
# epoch:84, batch_id:1, acc:1.0
# epoch:84, batch_id:2, acc:1.0
# epoch:85, batch_id:0, acc:1.0
# epoch:85, batch_id:1, acc:1.0
# epoch:85, batch_id:2, acc:1.0
# epoch:86, batch_id:0, acc:1.0
# epoch:86, batch_id:1, acc:1.0
# epoch:86, batch_id:2, acc:1.0
# epoch:87, batch_id:0, acc:1.0
# epoch:87, batch_id:1, acc:1.0
# epoch:87, batch_id:2, acc:1.0
# epoch:88, batch_id:0, acc:1.0
# epoch:88, batch_id:1, acc:1.0
# epoch:88, batch_id:2, acc:1.0
# epoch:89, batch_id:0, acc:1.0
# epoch:89, batch_id:1, acc:1.0
# epoch:89, batch_id:2, acc:1.0
# epoch:90, batch_id:0, acc:1.0
# epoch:90, batch_id:1, acc:1.0
# epoch:90, batch_id:2, acc:1.0
# epoch:91, batch_id:0, acc:1.0
# epoch:91, batch_id:1, acc:1.0
# epoch:91, batch_id:2, acc:1.0
# epoch:92, batch_id:0, acc:1.0
# epoch:92, batch_id:1, acc:1.0
# epoch:92, batch_id:2, acc:1.0
# epoch:93, batch_id:0, acc:1.0
# epoch:93, batch_id:1, acc:1.0
# epoch:93, batch_id:2, acc:1.0
# epoch:94, batch_id:0, acc:1.0
# epoch:94, batch_id:1, acc:1.0
# epoch:94, batch_id:2, acc:1.0
# epoch:95, batch_id:0, acc:1.0
# epoch:95, batch_id:1, acc:1.0
# epoch:95, batch_id:2, acc:1.0
# epoch:96, batch_id:0, acc:1.0
# epoch:96, batch_id:1, acc:1.0
# epoch:96, batch_id:2, acc:1.0
# epoch:97, batch_id:0, acc:1.0
# epoch:97, batch_id:1, acc:1.0
# epoch:97, batch_id:2, acc:1.0
# epoch:98, batch_id:0, acc:1.0
# epoch:98, batch_id:1, acc:1.0
# epoch:98, batch_id:2, acc:1.0
# epoch:99, batch_id:0, acc:1.0
# epoch:99, batch_id:1, acc:1.0
# epoch:99, batch_id:2, acc:1.0
